# %%
import requests
import pprint


#인증키 입력
encoding = '9OC1Z21JC85Q8F272Y30'
decoding = '9OC1Z21JC85Q8F272Y30'

#url 입력
url = 'http://api.koreafilm.or.kr/openapi-data2/wisenut/search_api/search_json2.jsp?collection=kmdb_new2&ServiceKey=9OC1Z21JC85Q8F272Y30'
params ={'ServiceKey' : decoding , 'pageNo' : '1', 'numOfRows' : '10', 'startCreateDt' : '2020', 'endCreateDt' : '20211103' }

response = requests.get(url)

# xml 내용
content = response.text

# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

# %%
pp.pprint(content)
# Out:
# ('\r\n'
#  '{"Query":"","KMAQuery":"","TotalCount":90494,"Data":[{"CollName":"kmdb_new2","TotalCount":90494,"Count":10,"Result":[{"DOCID":"F00142","movieId":"F","movieSeq":"00142","title":" '
#  '여호","titleEng":"Gone to Earth","titleOrg":"Gone to '
#  'Earth","titleEtc":"여호^Gone to Earth^여호^Gone to Earth^Gone to '
#  'Earth^귀향","prodYear":"1950","directors":{"director":[{"directorNm":"마이클 '
#  '파웰","directorEnNm":"Michael '
#  'Powell","directorId":"00102798"},{"directorNm":"에머릭 '
#  '프레스버거","directorEnNm":"Emeric '
#  'Pressburger","directorId":"00069726"}]},"actors":{"actor":[{"actorNm":"제니퍼 '
#  '존스","actorEnNm":"Jennifer Jones","actorId":"00049445"},{"actorNm":"데이빗 '
#  '파라","actorEnNm":"David Farrar","actorId":"00065653"},{"actorNm":"시릴 '
#  '쿠삭","actorEnNm":"Cyril Cusack","actorId":"00064203"},{"actorNm":"시빌 '
#  '손디크","actorEnNm":"Sybil Thorndike","actorId":"00118424"},{"actorNm":"에드워드 '
#  '채프만","actorEnNm":"Edward Chapman","actorId":"00150945"},{"actorNm":"에스몬드 '
# ...

# %%
import pandas as pd

# %%
df_kobis= pd.read_excel('KOBIS_개봉일람.xlsx')

# %%
df_kobis.head()
# Out:
#    순번         영화명           감독                              제작사  \
# 0   1          명량          김한민                        (주)빅스톤픽쳐스
# 1   2        극한직업          이병헌  (주)어바웃필름,영화사 해그림 주식회사,(주)씨제이이엔엠
# 2   3   신과함께-죄와 벌          김용화           리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 3   4        국제시장          윤제균              (주)제이케이필름,(주)씨제이이엔엠
# 4   5  어벤져스: 엔드게임  안소니 루소,조 루소                              NaN
#
#                   수입사                 배급사        개봉일  영화유형 영화형태  국적    전국  \
# 0                 NaN           (주)씨제이이엔엠 2014-07-30  개봉영화   장편  한국  1587
# 1                 NaN           (주)씨제이이엔엠 2019-01-23  개봉영화   장편  한국  1978
# 2                 NaN       롯데쇼핑㈜롯데엔터테인먼트 2017-12-20  개봉영화   장편  한국  1912
# 3                 NaN           (주)씨제이이엔엠 2014-12-17  개봉영화   장편  한국   966
# 4  월트디즈니컴퍼니코리아 유한책임회사  월트디즈니컴퍼니코리아 유한책임회사 2019-04-24  개봉영화   장편  미국  2835
#
#            전국.1      전국.2            서울     서울.1   장르        등급  영화구분
# ...

# %%
df_kobis.shape
# Out:
# (15914, 18)

# %%
df_kobis.rename(columns={'전국':'전국 스크린','전국.1':'전국 매출액','전국.2':'전국 관객수','서울':'서울 매출액','서울.1':'서울 관객수'}, inplace=True)

# %%
df_kobis.head()
# Out:
#    순번         영화명           감독                              제작사  \
# 0   1          명량          김한민                        (주)빅스톤픽쳐스
# 1   2        극한직업          이병헌  (주)어바웃필름,영화사 해그림 주식회사,(주)씨제이이엔엠
# 2   3   신과함께-죄와 벌          김용화           리얼라이즈픽쳐스(주),(주)덱스터스튜디오
# 3   4        국제시장          윤제균              (주)제이케이필름,(주)씨제이이엔엠
# 4   5  어벤져스: 엔드게임  안소니 루소,조 루소                              NaN
#
#                   수입사                 배급사        개봉일  영화유형 영화형태  국적  전국 스크린  \
# 0                 NaN           (주)씨제이이엔엠 2014-07-30  개봉영화   장편  한국    1587
# 1                 NaN           (주)씨제이이엔엠 2019-01-23  개봉영화   장편  한국    1978
# 2                 NaN       롯데쇼핑㈜롯데엔터테인먼트 2017-12-20  개봉영화   장편  한국    1912
# 3                 NaN           (주)씨제이이엔엠 2014-12-17  개봉영화   장편  한국     966
# 4  월트디즈니컴퍼니코리아 유한책임회사  월트디즈니컴퍼니코리아 유한책임회사 2019-04-24  개봉영화   장편  미국    2835
#
#          전국 매출액    전국 관객수        서울 매출액   서울 관객수   장르        등급  영화구분
# ...

# %%
print(df_kobis.shape)
# Out:
# (15914, 18)

# %%
df_kmdb= pd.read_excel('KMDB_Added_All.xlsx')

# %%
df_kmdb = df_kmdb.drop(['Unnamed: 0', 'kmdbUrl', 'titleEng', 'titleOrg','titleEtc'], axis=1)

# %%
df_kmdb.head()
# Out:
#     DOCID movieId  movieSeq             title  prodYear nation     company  \
# 0  F02551       F      2551               칠복성    1985.0     홍콩         NaN
# 1  F45221       F     45221   스왈로 탐험대와 아마존 해적    2016.0     영국   BBC Films
# 2  K17481       K     17481                물괴    2017.0   대한민국   ㈜태원엔터테인먼트
# 3  K16083       K     16083             싱글라이더    2016.0   대한민국  (주)퍼펙트스톰필름
# 4  F45133       F     45133           리즈와 파랑새    2018.0     일본    교토 애니메이션
#
#    runtime  rating           genre  \
# 0     98.0     NaN       액션,코메디,무협
# 1     97.0   전체관람가  가족,어드벤처,드라마,전쟁
# 2    105.0  15세관람가       액션,시대극/사극
# 3     97.0  15세관람가             드라마
# 4     90.0   전체관람가             드라마
#
#                                   directors.director  \
# 0  [{'directorNm': '홍금보', 'directorEnNm': 'Sammo ...
# 1  [{'directorNm': '필립파 로소프', 'directorEnNm': 'Ph...
# 2  [{'directorNm': '허종호', 'directorEnNm': 'Heo Jo...
# 3  [{'directorNm': '이주영', 'directorEnNm': 'LEE Zo...
# ...

# %%
print(df_kmdb.shape)
# Out:
# (9770, 18)

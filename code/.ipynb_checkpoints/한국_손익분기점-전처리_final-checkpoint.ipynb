# %%
import pandas as pd

# %%
adsfasdfasdfsadf

# %%
adfadfas

# %%
ahah

# %%
a

# %%
df= pd.read_csv('Movie_raw.csv')

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc         개봉일           제작비  네이버_기대지수  \
# 0       1183.0   723414.0  6.104165e+09  2018-09-12  1.250000e+10    1274.0
# 1        576.0   351276.0  2.685519e+09  2017-02-22  4.500000e+09    3838.0
# 2        696.0   336822.0  2.521026e+09  2018-06-27  2.500000e+09     494.0
# 3         54.0     7443.0  6.032025e+07  2018-10-25  1.000000e+08     162.0
# 4        106.0    24823.0  1.927298e+08  2018-11-22  2.200000e+08     800.0
# ..         ...        ...           ...         ...           ...       ...
# 570     1009.0  7759473.0  6.017358e+10  2015-12-16  1.000000e+10   13693.0
# 571      621.0   955175.0  7.405416e+09  2015-01-14  1.000000e+10   10731.0
# 572      838.0  8646758.0  6.624063e+10  2014-08-06  1.500000e+10    4941.0
# 573       14.0     1660.0  1.300650e+07  2014-08-07  5.000000e+06     247.0
# 574     1299.0  7231638.0  5.816558e+10  2017-12-27  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend
# 0         1629                22         773.0
# 1          581                19         387.0
# 2          943                30         616.0
# 3          111                 6           0.0
# 4          335                 5        1674.0
# ..         ...               ...           ...
# 570       1987               219         947.0
# 571       1196               124         886.0
# 572       1413               379           0.0
# 573        147                25         459.0
# 574       1830                61        2593.0
#
# [575 rows x 16 columns]

# %% [markdown]
# # 타겟 만들기

# %%
df['Target'] = df['제작비'] * 3 # 제작비의 3배를 계산해줌

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc         개봉일           제작비  네이버_기대지수  \
# 0       1183.0   723414.0  6.104165e+09  2018-09-12  1.250000e+10    1274.0
# 1        576.0   351276.0  2.685519e+09  2017-02-22  4.500000e+09    3838.0
# 2        696.0   336822.0  2.521026e+09  2018-06-27  2.500000e+09     494.0
# 3         54.0     7443.0  6.032025e+07  2018-10-25  1.000000e+08     162.0
# 4        106.0    24823.0  1.927298e+08  2018-11-22  2.200000e+08     800.0
# ..         ...        ...           ...         ...           ...       ...
# 570     1009.0  7759473.0  6.017358e+10  2015-12-16  1.000000e+10   13693.0
# 571      621.0   955175.0  7.405416e+09  2015-01-14  1.000000e+10   10731.0
# 572      838.0  8646758.0  6.624063e+10  2014-08-06  1.500000e+10    4941.0
# 573       14.0     1660.0  1.300650e+07  2014-08-07  5.000000e+06     247.0
# 574     1299.0  7231638.0  5.816558e+10  2017-12-27  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend        Target
# 0         1629                22         773.0  3.750000e+10
# 1          581                19         387.0  1.350000e+10
# 2          943                30         616.0  7.500000e+09
# 3          111                 6           0.0  3.000000e+08
# 4          335                 5        1674.0  6.600000e+08
# ..         ...               ...           ...           ...
# 570       1987               219         947.0  3.000000e+10
# 571       1196               124         886.0  3.000000e+10
# 572       1413               379           0.0  4.500000e+10
# 573        147                25         459.0  1.500000e+07
# 574       1830                61        2593.0  4.350000e+10
#
# [575 rows x 17 columns]

# %%
df.loc[df['Target']<df['salesAcc'],'Target'] = 1 # 매출액이 제작비 3배를 넘기면 1
df.loc[df['Target']>df['salesAcc'],'Target'] = 0 # 매출액이 제작비 3배를 못넘기면 0

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc         개봉일           제작비  네이버_기대지수  \
# 0       1183.0   723414.0  6.104165e+09  2018-09-12  1.250000e+10    1274.0
# 1        576.0   351276.0  2.685519e+09  2017-02-22  4.500000e+09    3838.0
# 2        696.0   336822.0  2.521026e+09  2018-06-27  2.500000e+09     494.0
# 3         54.0     7443.0  6.032025e+07  2018-10-25  1.000000e+08     162.0
# 4        106.0    24823.0  1.927298e+08  2018-11-22  2.200000e+08     800.0
# ..         ...        ...           ...         ...           ...       ...
# 570     1009.0  7759473.0  6.017358e+10  2015-12-16  1.000000e+10   13693.0
# 571      621.0   955175.0  7.405416e+09  2015-01-14  1.000000e+10   10731.0
# 572      838.0  8646758.0  6.624063e+10  2014-08-06  1.500000e+10    4941.0
# 573       14.0     1660.0  1.300650e+07  2014-08-07  5.000000e+06     247.0
# 574     1299.0  7231638.0  5.816558e+10  2017-12-27  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target
# 0         1629                22         773.0     0.0
# 1          581                19         387.0     0.0
# 2          943                30         616.0     0.0
# 3          111                 6           0.0     0.0
# 4          335                 5        1674.0     0.0
# ..         ...               ...           ...     ...
# 570       1987               219         947.0     1.0
# 571       1196               124         886.0     0.0
# 572       1413               379           0.0     1.0
# 573        147                25         459.0     0.0
# 574       1830                61        2593.0     1.0
#
# [575 rows x 17 columns]

# %%
df['Target'].value_counts()
# Out:
# 0.0    438
# 1.0    137
# Name: Target, dtype: int64

# %% [markdown]
# ## 배우/결국 안쓰는 피처가 됨

# %%
df['act_n'] = df['actors'].str.split(',')

# %%
for i in range(len(df['act_n'])):
    df.loc[i,'act_n'] = len(df['act_n'][i])

# %% [markdown]
# ## 배급사 합치기

# %%
df_pro = pd.read_excel('KOBIS_개봉일람.xlsx')

# %%
df_pro = df_pro.drop(['순번', '감독', '제작사', '수입사', '개봉일', '영화유형', '영화형태', '국적',
       '전국', '전국.1', '전국.2', '서울', '서울.1', '장르', '등급', '영화구분'], axis=1)

# %%
df_pro.rename(columns={'영화명':'title'}, inplace=True)

# %%
df_pro = df_pro.drop_duplicates()

# %%
df = pd.merge(df,df_pro, how='left', on='title' )

# %%
df = df.drop_duplicates('title', keep='first')

# %% [markdown]
# ## 배급사 전처리

# %%
df['배급사']=df['배급사'].astype('str')

# %%
df[df['배급사']=='nan'] # 널값채우기
# Out:
#      Unnamed: 0 title directors  \
# 261         250    출국       노규엽
# 592         574  1987       장준환
#
#                                                 actors genre        등급  국적  \
# 261  이범수, 연우진, 박혁권, 박주미, 이현정, 김보민, 로버트 미카, 전무송, 남문철...   드라마  15세이상관람가  한국
# 592  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc         개봉일           제작비  네이버_기대지수  \
# 261      274.0    81722.0  6.395218e+08  2018-11-14  6.500000e+09     150.0
# 592     1299.0  7231638.0  5.816558e+10  2017-12-27  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target act_n  배급사
# 261        427                16        1142.0     0.0    54  nan
# 592       1830                61        2593.0     1.0   295  nan

# %%
df.at[261, '배급사'] = '스파일이엔트'

df.at[592, '배급사'] = 'CJ'

# %%
df[df['배급사']=='nan'] #널값이 있는지 다시 확인
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, directors, actors, genre, 등급, 국적, screenCnt, audiAcc, salesAcc, 개봉일, 제작비, 네이버_기대지수, star_buzz, movie_buzz_naver, google_trend, Target, act_n, 배급사]
# Index: []

# %%
df['배급사'].value_counts()[:10] #160개의 배급사 존재
# Out:
# (주)씨제이이엔엠              78
# (주)넥스트엔터테인먼트월드(NEW)    58
# (주)쇼박스                 43
# 롯데쇼핑㈜롯데엔터테인먼트          39
# CGV아트하우스               24
# (주)리틀빅픽쳐스              23
# 롯데컬처웍스(주)롯데엔터테인먼트      21
# 메가박스중앙(주)플러스엠          21
# ㈜인디스토리                 16
# (주)엣나인필름               11
# Name: 배급사, dtype: int64

# %%
df['배급사'] = df['배급사'].str.replace('㈜','')

# %%
# 배급사 이름 전처리, 비슷한 이름 합쳐주는 함수 만들기
def get_dis(x) :
    if 'CJ' in x or 'CGV' in x or '씨제이' in x :
        return 'CJ'
    elif '쇼박스' in x :
        return '쇼박스'
    elif 'SK' in x or '에스케이' in x:
        return 'SK'
    elif '리틀빅픽' in x :
        return '리틀빅픽처스'
    elif '스폰지' in x :
        return '스폰지'
    elif '싸이더스' in x :
        return '싸이더스'
    elif '에이원' in x :
        return '에이원'
    elif '마인스' in x :
        return '마인스'
    elif '마운틴픽' in x :
        return '마운틴픽처스'
    elif '디씨드' in x :
        return '디씨드'
    elif '드림팩트' in x :
        return '드림팩트'
    elif '메가박스' in x :
        return '메가박스'
    elif '마운틴' in x :
        return '마운틴'
    elif '롯데' in x :
        return '롯데'
    elif 'KBS' in x :
        return 'KBS'
    elif '제이앤씨미디어그룹' in x :
        return '제이앤씨미디어그룹'
    elif '월트디즈니' in x :
        return '월트디즈니'
    elif '그린나래' in x :
        return '그린나래'
    elif 'KTG상상마당' in x or 'KT'in x :
        return 'KTG상상마당'
    elif 'TJOY' in x or 'T-JOY' in x:
        return 'TJOY'
    elif '디오시네마' in x :
        return '디오시네마'
    elif '스톰픽쳐스' in x :
        return '스톰픽쳐스'
    elif '디스테이션' in x :
        return '디스테이션'
    elif '더블앤조이' in x :
        return '디스테이션'
    elif 'CBS' in x :
        return 'CBS'
    elif 'CBS' in x :
        return 'CBS'
    elif '더쿱' in x :
        return '더쿱'
    elif '더콘텐츠온' in x :
        return '더콘텐츠온'
    elif '소니픽쳐스' in x :
        return '소니픽쳐스'
    elif '이수' in x :
        return '이수'
    elif '워너' in x :
        return '워너브라더스'
    elif '삼백' in x :
        return '삼백상회'
    elif '폭스' in x :
        return '폭스코리아'
    elif '엣나인' in x :
        return '엣나인필름'
    elif '티캐스트' in x :
        return '티캐스트'
    elif '콘텐츠판다' in x :
        return '콘텐츠판다'
    elif '판씨네마' in x :
        return '판씨네마'
    elif '키다리' in x :
        return '키다리이엔티'
    elif '스마일이' in x :
        return '스마일이엔티'
    elif '팝엔' in x :
        return '팝엔터테인먼트' 
    elif '오퍼스' in x :
        return '오퍼스픽쳐스' 
    elif '와이드' in x :
        return '와이드릴리즈' 
    elif '오드' in x :
        return '오드' 
    elif '조이앤' in x :
        return '조이앤시네마' 
    elif '박수' in x :
        return '박수엔터테인먼트' 
    elif '찬란' in x :
        return '찬란'
    elif '얼리' in x :
        return '얼리버드'
    elif '영화사빅' in x :
        return '영화사빅'
    elif '에이스' in x :
        return '에이스메이커'
    elif '퍼스트런' in x :
        return '퍼스트런'
    elif 'MM' in x or 'M&M' in x:
        return 'MM인터내셔널'
    elif '드림웨스트' in x :
        return '드림웨스트픽쳐스'
    elif '홀리가든' in x :
        return '홀리가든'
    elif 'R&R' in x :
        return 'RR프로덕션'
    elif '머스트' in x :
        return '머스트씨무비'
    elif '블룸즈' in x :
        return '블룸즈베리'
    elif '모쿠' in x :
        return '모쿠슈라'
    elif '니버설' in x :
        return '유니버설픽쳐스'
    elif '시네마달' in x :
        return '시네마달'
    else :
        return x

# %%
df['배급사'] = df['배급사'].apply(get_dis) # 만든함수 적용

# %%
df['배급사'].nunique() # 총 115개의 최종적인 배급사 수 확인/ 160개에서 115개로 줄어든것을 확인할 수 있음
# Out:
# 115

# %%
df['배급사'].value_counts()[:8] # 배급사마다의 영화 개수 확인하기
# Out:
# CJ                     116
# 롯데                      61
# (주)넥스트엔터테인먼트월드(NEW)     58
# 쇼박스                     45
# 리틀빅픽처스                  30
# 메가박스                    25
# 인디스토리                   16
# 엣나인필름                   13
# Name: 배급사, dtype: int64

# %%
distributor_list = df['배급사'].value_counts()[:8] # 상위 8개 빼고 기타처리하는 함수 만들기
def func(distributor):
    if distributor in distributor_list:
        return distributor
    else:
        return '기타'

# %%
df['배급사'] = df['배급사'].apply(lambda x : func(x)) #함수적용

# %%
tr_dist_rank =df.groupby('배급사').audiAcc.median().reset_index(name = 'dist_rank').sort_values(by = 'dist_rank',ascending=False)
tr_dist_rank # 각 배급사의 영화 관객수의 중위값으로 상위 배급사 순위 매기기, 평균값보다 의미 있는 결과를 낳아서 중위값으로 함
# Out:
#                    배급사  dist_rank
# 6                  쇼박스  2424330.0
# 0  (주)넥스트엔터테인먼트월드(NEW)  1535021.5
# 1                   CJ  1426615.0
# 3                   롯데  1110246.0
# 5                 메가박스   984265.0
# 4               리틀빅픽처스   112888.5
# 7                엣나인필름   103054.0
# 2                   기타     8680.0
# 8                인디스토리     2216.5

# %%
tr_dist_rank['dist_rank'] = [i + 1 for i in range(tr_dist_rank.shape[0])]
tr_dist_rank # 상위 배급사 순위 처리하기, #인디스토리는 인디 영화 배급사
# Out:
#                    배급사  dist_rank
# 6                  쇼박스          1
# 0  (주)넥스트엔터테인먼트월드(NEW)          2
# 1                   CJ          3
# 3                   롯데          4
# 5                 메가박스          5
# 4               리틀빅픽처스          6
# 7                엣나인필름          7
# 2                   기타          8
# 8                인디스토리          9

# %%
df = pd.merge(df, tr_dist_rank, how = 'left')

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc         개봉일           제작비  네이버_기대지수  \
# 0       1183.0   723414.0  6.104165e+09  2018-09-12  1.250000e+10    1274.0
# 1        576.0   351276.0  2.685519e+09  2017-02-22  4.500000e+09    3838.0
# 2        696.0   336822.0  2.521026e+09  2018-06-27  2.500000e+09     494.0
# 3         54.0     7443.0  6.032025e+07  2018-10-25  1.000000e+08     162.0
# 4        106.0    24823.0  1.927298e+08  2018-11-22  2.200000e+08     800.0
# ..         ...        ...           ...         ...           ...       ...
# 570     1009.0  7759473.0  6.017358e+10  2015-12-16  1.000000e+10   13693.0
# 571      621.0   955175.0  7.405416e+09  2015-01-14  1.000000e+10   10731.0
# 572      838.0  8646758.0  6.624063e+10  2014-08-06  1.500000e+10    4941.0
# 573       14.0     1660.0  1.300650e+07  2014-08-07  5.000000e+06     247.0
# 574     1299.0  7231638.0  5.816558e+10  2017-12-27  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target act_n  \
# 0         1629                22         773.0     0.0   121
# 1          581                19         387.0     0.0    50
# 2          943                30         616.0     0.0    96
# 3          111                 6           0.0     0.0    12
# 4          335                 5        1674.0     0.0    30
# ..         ...               ...           ...     ...   ...
# 570       1987               219         947.0     1.0    73
# 571       1196               124         886.0     0.0    70
# 572       1413               379           0.0     1.0   148
# 573        147                25         459.0     0.0    32
# 574       1830                61        2593.0     1.0   295
#
#                      배급사  dist_rank
# 0                     롯데          4
# 1                     기타          8
# 2    (주)넥스트엔터테인먼트월드(NEW)          2
# 3                     기타          8
# 4                     CJ          3
# ..                   ...        ...
# 570                   CJ          3
# 571  (주)넥스트엔터테인먼트월드(NEW)          2
# 572                   롯데          4
# 573                엣나인필름          7
# 574                   CJ          3
#
# [575 rows x 20 columns]

# %% [markdown]
# ## 장르 전처리

# %%
df[df['genre']=='기타'] # 기타라고 되어 잇는 장르 값 채우기
# Out:
#      Unnamed: 0  title directors  \
# 185         185  인트로덕션       홍상수
#
#                                                actors genre        등급  국적  \
# 185  신석호, 박미소, 김영호, 기주봉, 예지원, 조소연, 서영화, 김민희, 조윤희, 하성국    기타  12세이상관람가  한국
#
#      screenCnt  audiAcc    salesAcc         개봉일         제작비  네이버_기대지수  \
# 185       91.0   6185.0  55369270.0  2021-05-27  50000000.0     284.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target act_n 배급사  dist_rank
# 185        142                 7         341.0     0.0    10  기타          8

# %%
df.at[185, 'genre'] = '드라마'

# %%
df[df['genre']=='기타'] # 널값이 없는지 다시 확인
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, title, directors, actors, genre, 등급, 국적, screenCnt, audiAcc, salesAcc, 개봉일, 제작비, 네이버_기대지수, star_buzz, movie_buzz_naver, google_trend, Target, act_n, 배급사, dist_rank]
# Index: []

# %%
df.groupby('genre').audiAcc.median().sort_values(ascending=False) # 각 장르의 관객수의 중위값으로 순위 정함(평균값으로 해도 순위변동이 없었음)
# Out:
# genre
# 어드벤처      8252669.0
# 사극        2022527.0
# 범죄        1736428.0
# 전쟁        1717566.0
# 액션        1638437.0
# 판타지       1535154.5
# 스릴러        616481.0
# 코미디        507257.0
# 미스터리       332993.0
# 멜로/로맨스     316780.0
# 공포(호러)     288016.0
# SF         102170.0
# 드라마         95542.0
# 가족           8327.0
# 다큐멘터리        8138.5
# 뮤지컬          1027.0
# Name: audiAcc, dtype: float64

# %%
df['genre_rank'] = df.genre.map({'뮤지컬' : 16,'다큐멘터리' : 15, '가족' : 14, '드라마' : 13, 'SF' : 12, '공포(호러)' : 11, '멜로/로맨스' : 10, '미스터리' : 9, '코미디':8,'스릴러':7,'판타지':6,'액션':5,'전쟁':4,'범죄':3,'사극':2,'어드벤처':1})
#위에서 확인 한 결과로 순위를 적어줌

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc  ...           제작비  네이버_기대지수  \
# 0       1183.0   723414.0  6.104165e+09  ...  1.250000e+10    1274.0
# 1        576.0   351276.0  2.685519e+09  ...  4.500000e+09    3838.0
# 2        696.0   336822.0  2.521026e+09  ...  2.500000e+09     494.0
# 3         54.0     7443.0  6.032025e+07  ...  1.000000e+08     162.0
# 4        106.0    24823.0  1.927298e+08  ...  2.200000e+08     800.0
# ..         ...        ...           ...  ...           ...       ...
# 570     1009.0  7759473.0  6.017358e+10  ...  1.000000e+10   13693.0
# 571      621.0   955175.0  7.405416e+09  ...  1.000000e+10   10731.0
# 572      838.0  8646758.0  6.624063e+10  ...  1.500000e+10    4941.0
# 573       14.0     1660.0  1.300650e+07  ...  5.000000e+06     247.0
# 574     1299.0  7231638.0  5.816558e+10  ...  1.450000e+10   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target  act_n  \
# 0         1629                22         773.0     0.0    121
# 1          581                19         387.0     0.0     50
# 2          943                30         616.0     0.0     96
# 3          111                 6           0.0     0.0     12
# 4          335                 5        1674.0     0.0     30
# ..         ...               ...           ...     ...    ...
# 570       1987               219         947.0     1.0     73
# 571       1196               124         886.0     0.0     70
# 572       1413               379           0.0     1.0    148
# 573        147                25         459.0     0.0     32
# 574       1830                61        2593.0     1.0    295
#
#                      배급사 dist_rank  genre_rank
# 0                     롯데         4           5
# 1                     기타         8          13
# 2    (주)넥스트엔터테인먼트월드(NEW)         2          13
# 3                     기타         8          13
# 4                     CJ         3          13
# ..                   ...       ...         ...
# 570                   CJ         3          13
# 571  (주)넥스트엔터테인먼트월드(NEW)         2          13
# 572                   롯데         4           1
# 573                엣나인필름         7           8
# 574                   CJ         3          13
#
# [575 rows x 21 columns]

# %% [markdown]
# ## 등급 원핫(빼는게 좋은듯)

# %%
#df = pd.get_dummies(columns = ['등급'], data = df)

# %% [markdown]
# ## 감독 전처리

# %%
df['directors'].nunique() #총 427명의 감독이 존재
# Out:
# 427

# %%
df['directors'].value_counts()[:100]
# Out:
# 이준익    6
# 조정래    4
# 류승완    4
# 김홍선    4
# 고봉수    4
#       ..
# 김주환    2
# 백승화    2
# 최국희    2
# 김지영    2
# 손용호    2
# Name: directors, Length: 100, dtype: int64

# %%
director_list = df['directors'].value_counts()[:100] # 영화 2개 미만의 영화를 만든 감독은 기타 처리하는 함수 만들기
def cont_func(director):
    if director in director_list:
        return director
    else:
        return '기타'

# %%
df['directors'] = df['directors'].apply(lambda x : cont_func(x)) #함수적용

# %%
tr_direct_rank = df.groupby('directors').audiAcc.mean().reset_index(name = 'direct_rank').sort_values(by = 'direct_rank', ascending=False)
tr_direct_rank
# 감독들의 영화 관객수를 평균값으로 감독들의 순위 매김, 중앙값보다 의미 있는 결과를 보여서 평균값으로 함
# 실제로 유명한 감독들이 상위권에 있는 것을 확인할 수 있음
# Out:
#    directors   direct_rank
# 90       최동훈  1.284452e+07
# 26       김한민  1.254033e+07
# 41       봉준호  9.613966e+06
# 15       김용화  9.330964e+06
# 61       이석훈  8.203116e+06
# ..       ...           ...
# 75       이혁종  3.986000e+03
# 34       박석영  2.908000e+03
# 3        고봉수  2.345250e+03
# 38       백승기  2.281000e+03
# 84       정형석  9.650000e+02
#
# [101 rows x 2 columns]

# %%
tr_direct_rank[:70]
# Out:
#    directors   direct_rank
# 90       최동훈  1.284452e+07
# 26       김한민  1.254033e+07
# 41       봉준호  9.613966e+06
# 15       김용화  9.330964e+06
# 61       이석훈  8.203116e+06
# ..       ...           ...
# 72       이철하  8.399023e+05
# 6         기타  7.903726e+05
# 83       정지우  7.794115e+05
# 11    김선, 김곡  7.134430e+05
# 14       김용완  6.491440e+05
#
# [70 rows x 2 columns]

# %%
tr_direct_rank['direct_rank'] = [i + 1 for i in range(tr_direct_rank.shape[0])] #순위 적용
tr_direct_rank
# Out:
#    directors  direct_rank
# 90       최동훈            1
# 26       김한민            2
# 41       봉준호            3
# 15       김용화            4
# 61       이석훈            5
# ..       ...          ...
# 75       이혁종           97
# 34       박석영           98
# 3        고봉수           99
# 38       백승기          100
# 84       정형석          101
#
# [101 rows x 2 columns]

# %%
tr_direct_rank[tr_direct_rank['directors'] == '기타'] # 기타의 순위 확인해봄
# Out:
#   directors  direct_rank
# 6        기타           67

# %%
df= pd.merge(df, tr_direct_rank, how = 'left')
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴        기타
# 1             1         싱글라이더        기타
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주        기타
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987        기타
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc  ... 네이버_기대지수  star_buzz  \
# 0       1183.0   723414.0  6.104165e+09  ...   1274.0       1629
# 1        576.0   351276.0  2.685519e+09  ...   3838.0        581
# 2        696.0   336822.0  2.521026e+09  ...    494.0        943
# 3         54.0     7443.0  6.032025e+07  ...    162.0        111
# 4        106.0    24823.0  1.927298e+08  ...    800.0        335
# ..         ...        ...           ...  ...      ...        ...
# 570     1009.0  7759473.0  6.017358e+10  ...  13693.0       1987
# 571      621.0   955175.0  7.405416e+09  ...  10731.0       1196
# 572      838.0  8646758.0  6.624063e+10  ...   4941.0       1413
# 573       14.0     1660.0  1.300650e+07  ...    247.0        147
# 574     1299.0  7231638.0  5.816558e+10  ...  13877.0       1830
#
#      movie_buzz_naver  google_trend  Target  act_n                  배급사  \
# 0                  22         773.0     0.0    121                   롯데
# 1                  19         387.0     0.0     50                   기타
# 2                  30         616.0     0.0     96  (주)넥스트엔터테인먼트월드(NEW)
# 3                   6           0.0     0.0     12                   기타
# 4                   5        1674.0     0.0     30                   CJ
# ..                ...           ...     ...    ...                  ...
# 570               219         947.0     1.0     73                   CJ
# 571               124         886.0     0.0     70  (주)넥스트엔터테인먼트월드(NEW)
# 572               379           0.0     1.0    148                   롯데
# 573                25         459.0     0.0     32                엣나인필름
# 574                61        2593.0     1.0    295                   CJ
#
#     dist_rank genre_rank  direct_rank
# 0           4          5           67
# 1           8         13           67
# 2           2         13           41
# 3           8         13           94
# 4           3         13           67
# ..        ...        ...          ...
# 570         3         13            5
# 571         2         13           72
# 572         4          1            5
# 573         7          8          100
# 574         3         13           67
#
# [575 rows x 22 columns]

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴        기타
# 1             1         싱글라이더        기타
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주        기타
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987        기타
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ..                                                 ...   ...       ...  ..
# 570  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...   드라마  12세이상관람가  한국
# 571  하정우, 하지원, 남다름, 노강민, 전현석, 전혜진, 장광, 민무제, 주진모, 성동...   드라마  12세이상관람가  한국
# 572  손예진, 유해진, 김원해, 박철민, 조달환, 신정근, 설리, 이이경, 이경영, 김경...  어드벤처  12세이상관람가  한국
# 573  백승기, 손이용, 박지나, 조한철, 김선호, 성충경, 신예주, 백대현, 이순자, 손...   코미디   청소년관람불가  한국
# 574  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...   드라마  15세이상관람가  한국
#
#      screenCnt    audiAcc      salesAcc  ... 네이버_기대지수  star_buzz  \
# 0       1183.0   723414.0  6.104165e+09  ...   1274.0       1629
# 1        576.0   351276.0  2.685519e+09  ...   3838.0        581
# 2        696.0   336822.0  2.521026e+09  ...    494.0        943
# 3         54.0     7443.0  6.032025e+07  ...    162.0        111
# 4        106.0    24823.0  1.927298e+08  ...    800.0        335
# ..         ...        ...           ...  ...      ...        ...
# 570     1009.0  7759473.0  6.017358e+10  ...  13693.0       1987
# 571      621.0   955175.0  7.405416e+09  ...  10731.0       1196
# 572      838.0  8646758.0  6.624063e+10  ...   4941.0       1413
# 573       14.0     1660.0  1.300650e+07  ...    247.0        147
# 574     1299.0  7231638.0  5.816558e+10  ...  13877.0       1830
#
#      movie_buzz_naver  google_trend  Target  act_n                  배급사  \
# 0                  22         773.0     0.0    121                   롯데
# 1                  19         387.0     0.0     50                   기타
# 2                  30         616.0     0.0     96  (주)넥스트엔터테인먼트월드(NEW)
# 3                   6           0.0     0.0     12                   기타
# 4                   5        1674.0     0.0     30                   CJ
# ..                ...           ...     ...    ...                  ...
# 570               219         947.0     1.0     73                   CJ
# 571               124         886.0     0.0     70  (주)넥스트엔터테인먼트월드(NEW)
# 572               379           0.0     1.0    148                   롯데
# 573                25         459.0     0.0     32                엣나인필름
# 574                61        2593.0     1.0    295                   CJ
#
#     dist_rank genre_rank  direct_rank
# 0           4          5           67
# 1           8         13           67
# 2           2         13           41
# 3           8         13           94
# 4           3         13           67
# ..        ...        ...          ...
# 570         3         13            5
# 571         2         13           72
# 572         4          1            5
# 573         7          8          100
# 574         3         13           67
#
# [575 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 575 entries, 0 to 574
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        575 non-null    int64
#  1   title             575 non-null    object
#  2   directors         575 non-null    object
#  3   actors            575 non-null    object
#  4   genre             575 non-null    object
#  5   등급                575 non-null    object
#  6   국적                575 non-null    object
#  7   screenCnt         575 non-null    float64
#  8   audiAcc           575 non-null    float64
#  9   salesAcc          575 non-null    float64
#  10  개봉일               575 non-null    object
#  11  제작비               575 non-null    float64
#  12  네이버_기대지수          575 non-null    float64
#  13  star_buzz         575 non-null    int64
#  14  movie_buzz_naver  575 non-null    int64
#  15  google_trend      575 non-null    float64
#  16  Target            575 non-null    float64
#  17  act_n             575 non-null    object
#  18  배급사               575 non-null    object
#  19  dist_rank         575 non-null    int64
#  20  genre_rank        575 non-null    int64
#  21  direct_rank       575 non-null    int64
# dtypes: float64(7), int64(6), object(9)
# memory usage: 103.3+ KB

# %%
#필요없는 피처 삭제하기
df_fin = df.drop(['title','actors','배급사','genre','국적','directors','개봉일','audiAcc','salesAcc','제작비','등급'], axis=1)

# %%
df_fin['Target']=df_fin['Target'].astype(int)

# %%
df_fin['act_n'] = df_fin['act_n'].astype(int)

# %%
# 칼럼 위치 정리하기
df_fin = df_fin[['screenCnt','act_n','dist_rank','genre_rank','direct_rank','네이버_기대지수','star_buzz','movie_buzz_naver','google_trend','Target']]

# %%
df_fin
# Out:
#      screenCnt  act_n  dist_rank  genre_rank  direct_rank  네이버_기대지수  \
# 0       1183.0    121          4           5           67    1274.0
# 1        576.0     50          8          13           67    3838.0
# 2        696.0     96          2          13           41     494.0
# 3         54.0     12          8          13           94     162.0
# 4        106.0     30          3          13           67     800.0
# ..         ...    ...        ...         ...          ...       ...
# 570     1009.0     73          3          13            5   13693.0
# 571      621.0     70          2          13           72   10731.0
# 572      838.0    148          4           1            5    4941.0
# 573       14.0     32          7           8          100     247.0
# 574     1299.0    295          3          13           67   13877.0
#
#      star_buzz  movie_buzz_naver  google_trend  Target
# 0         1629                22         773.0       0
# 1          581                19         387.0       0
# 2          943                30         616.0       0
# 3          111                 6           0.0       0
# 4          335                 5        1674.0       0
# ..         ...               ...           ...     ...
# 570       1987               219         947.0       1
# 571       1196               124         886.0       0
# 572       1413               379           0.0       1
# 573        147                25         459.0       0
# 574       1830                61        2593.0       1
#
# [575 rows x 10 columns]

# %%
df_fin.corr()
# Out:
#                   screenCnt     act_n  dist_rank  genre_rank  direct_rank  \
# screenCnt          1.000000  0.489078  -0.586460   -0.432619    -0.574397
# act_n              0.489078  1.000000  -0.334343   -0.323091    -0.372314
# dist_rank         -0.586460 -0.334343   1.000000    0.354313     0.392187
# genre_rank        -0.432619 -0.323091   0.354313    1.000000     0.316747
# direct_rank       -0.574397 -0.372314   0.392187    0.316747     1.000000
# 네이버_기대지수           0.465925  0.356361  -0.262325   -0.159123    -0.239277
# star_buzz          0.768050  0.501961  -0.576039   -0.390730    -0.599283
# movie_buzz_naver   0.298548  0.300912  -0.402147   -0.221699    -0.426734
# google_trend       0.139943  0.130262  -0.207793   -0.051566    -0.034405
# Target             0.262076  0.065556  -0.271784   -0.081974    -0.285191
#
#                   네이버_기대지수  star_buzz  movie_buzz_naver  google_trend  \
# screenCnt         0.465925   0.768050          0.298548      0.139943
# act_n             0.356361   0.501961          0.300912      0.130262
# dist_rank        -0.262325  -0.576039         -0.402147     -0.207793
# genre_rank       -0.159123  -0.390730         -0.221699     -0.051566
# direct_rank      -0.239277  -0.599283         -0.426734     -0.034405
# 네이버_기대지수          1.000000   0.456861          0.305710      0.088969
# star_buzz         0.456861   1.000000          0.576394      0.174367
# movie_buzz_naver  0.305710   0.576394          1.000000      0.112307
# google_trend      0.088969   0.174367          0.112307      1.000000
# Target            0.171784   0.284791          0.352464      0.068763
#
#                     Target
# screenCnt         0.262076
# act_n             0.065556
# dist_rank        -0.271784
# genre_rank       -0.081974
# direct_rank      -0.285191
# 네이버_기대지수          0.171784
# star_buzz         0.284791
# movie_buzz_naver  0.352464
# google_trend      0.068763
# Target            1.000000

# %%
import seaborn as sns
from matplotlib import pyplot as plt
corr28 = df_fin.corr()

# %%
plt.rcParams['font.family'] = 'NanumGothic' # 한글 깨짐 고치기
plt.rcParams['axes.unicode_minus'] = False # 음수, 마이너스 깨짐 고치기

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data = corr28, annot=True, linewidths=.5, cmap='Blues')
plt.title('Correlation between features', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %%
df_fin['Target'].value_counts() # 1 이면 손익분기점을 넘긴 영화(흥행), 0이면 손익분기점을 넘기지 못한 영화
# Out:
# 0    438
# 1    137
# Name: Target, dtype: int64

# %%
#df_fin.to_csv('전처리_final.csv', index=False) #전처리 완료되면 파일로 저장

# %% [markdown]
# # train_test_split

# %%
# 타겟값과 피처값을 나눔
y = df_fin['Target']
x = df_fin.drop('Target', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=100)

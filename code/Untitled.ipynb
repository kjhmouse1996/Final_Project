# %%
import pandas as pd

# %%
df_key = pd.read_csv('../data/final3.csv')

# %%
df_key = df_key[df_key['국적']=='한국']

# %%
df_key = df_key[['title', 'keywords']]

# %%
df_key
# Out:
#                 title                        keywords
# 0     스왈로 탐험대와 아마존 해적            여름휴가,외딴섬,아이들,모험,소설원작
# 1                  물괴           조선시대,전염병,괴물,시대극/사극,사투
# 2               싱글라이더     기러기아빠,호주,오스트레일리아,반전,반전영화,동물
# 3             리즈와 파랑새  십대소녀,단짝친구,외톨이,고3,합주,졸업반,마지막 연주
# 4               레드 후드                괴물,성에 갇힌 남녀,감옥탈출
# ...               ...                             ...
# 6387            파라노이아                             NaN
# 6388         춘하추동 로맨스            고백,허세,내숭,현실연애,옴니버스영화
# 6389          4명의 암살자                             NaN
# 6390             변종샤크                돌연변이,공격,상어,죽음,자연
# 6391            터널 3D                        실종,터널,3D
#
# [6392 rows x 2 columns]

# %%
df_korea = pd.read_csv('../data/Movie_raw.csv')

# %%
df_korea
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ...

# %%
df = pd.merge(df_korea,df_key, how='left', on='title' )

# %%
df
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570          히말라야       이석훈
# 571         571           허삼관       하정우
# 572         572  해적: 바다로 간 산적       이석훈
# 573         573           숫호구       백승기
# 574         574          1987       장준환
#
#                                                 actors genre        등급  국적  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...    액션  15세이상관람가  한국
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...   드라마  15세이상관람가  한국
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...   드라마  12세이상관람가  한국
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...   드라마  15세이상관람가  한국
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...   드라마  12세이상관람가  한국
# ...

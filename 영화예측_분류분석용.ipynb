# %% [markdown]
# # 분류분석

# %%
import pandas as pd

# %%
df = pd.read_csv('data_merge수정2.csv')

# %%
df = df.drop(['Unnamed: 0','runtime','keywords','plots'], axis=1)

# %% [markdown]
# ## 타겟값 만들기

# %%
df['Target'] = df['audiAcc']

# %%
df.loc[df['Target']<1000000,'Target'] = 11
df.loc[(df['Target']>=1000000)&(df['Target']<2000000),'Target'] = 10
df.loc[(df['Target']>=2000000)&(df['Target']<3000000),'Target'] = 9
df.loc[(df['Target']>=3000000)&(df['Target']<4000000),'Target'] = 8
df.loc[(df['Target']>=4000000)&(df['Target']<5000000),'Target'] = 7
df.loc[(df['Target']>=5000000)&(df['Target']<6000000),'Target'] = 6
df.loc[(df['Target']>=6000000)&(df['Target']<7000000),'Target'] = 5
df.loc[(df['Target']>=7000000)&(df['Target']<8000000),'Target'] = 4
df.loc[(df['Target']>=8000000)&(df['Target']<9000000),'Target'] = 3
df.loc[(df['Target']>=9000000)&(df['Target']<10000000),'Target'] = 2
df.loc[df['Target']>=10000000,'Target'] = 1

# %%
df['Target']
# Out:
# 0       11
# 1       11
# 2       11
# 3       11
# 4       11
#         ..
# 6376    11
# 6377    11
# 6378    11
# 6379    11
# 6380    11
# Name: Target, Length: 6381, dtype: int64

# %%
df['act_n'] = df['actors'].str.split(',')

# %%
for i in range(len(df['act_n'])):
    df.loc[i,'act_n'] = len(df['act_n'][i])

# %% [markdown]
# ## 배급사 합치기

# %%
df2 = pd.read_excel('../data/KOBIS_개봉일람.xlsx')

# %%
df2.columns
# Out:
# Index(['순번', '영화명', '감독', '제작사', '수입사', '배급사', '개봉일', '영화유형', '영화형태', '국적',
#        '전국', '전국.1', '전국.2', '서울', '서울.1', '장르', '등급', '영화구분'],
#       dtype='object')

# %%
df2 = df2.drop(['순번', '감독', '제작사', '수입사', '개봉일', '영화유형', '영화형태', '국적',
       '전국', '전국.1', '전국.2', '서울', '서울.1', '장르', '등급', '영화구분'], axis=1)

# %%
df2.rename(columns={'영화명':'title'}, inplace=True)

# %%
df2 = df2.drop_duplicates()

# %%
df3 = pd.merge(df,df2, how='left', on='title' )

# %%
df3 = df3.drop_duplicates('title', keep='first')

# %% [markdown]
# ## 배급사 전처리

# %%
df3['배급사']=df3['배급사'].astype('str')

# %%
df3[df3['배급사']=='nan']
# Out:
#      title directors                                             actors  \
# 93    1987       장준환  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...
# 327     22       구오커                              박차순, 린아이란, 리메이진, 리아이롄
# 2399   355   사이먼 킨버그            제시카 차스테인, 다이안 크루거, 페넬로페 크루즈, 루피타 뇽, 판빙빙
# 2417  2067     세스 라니  코디 스밋-맥피, 라이언 콴튼, 다미안 월셔 하울링, 리안나 월스먼, 에런 글레낸,...
# 2610   800        관후                  어우 하오, 두순, 장유호, 당예흔, 강무, 야오천, 황지충
# 2820  1917     샘 맨데스  조지 맥케이, 딘-찰스 채프먼, 콜린 퍼스, 베네딕 컴버배치, 마크 스트롱, 앤드류...
# 2861    출국       노규엽  이범수, 연우진, 박혁권, 박주미, 이현정, 김보민, 로버트 미카, 전무송, 남문철...
# 5604    33   파트리샤 리겐  안토니오 반데라스, 로드리고 산토로, 줄리엣 비노쉬, 제임스 브로딘, 루 다이아몬드...
#
#       genre        등급         개봉일  국적  screenCnt      salesAcc  audiAcc  \
# 93      드라마  15세이상관람가  2017-12-27  한국       1299  5.816558e+10  7231638
# 327   다큐멘터리     전체관람가  2018-08-14  한국         31  1.866800e+07     2434
# 2399     액션  15세이상관람가  2022-02-09  미국        540  3.836136e+08    42951
# ...

# %%
df3.at[2861, '배급사'] = '트리플픽쳐스'
df3.at[2820, '배급사'] = '스파일이엔트'
df3.at[5604, '배급사'] = '나이너스엔터테인먼트'
df3.at[2399, '배급사'] = '제이앤씨미디어그룹'
df3.at[2417, '배급사'] = '예지림엔터테인먼트'
df3.at[2610, '배급사'] = '더콘텐츠온'
df3.at[327, '배급사'] = '메가박스'
df3.at[93, '배급사'] = 'CJ'

# %%
df3[df3['배급사']=='nan']
# Out:
# Empty DataFrame
# Columns: [title, directors, actors, genre, 등급, 개봉일, 국적, screenCnt, salesAcc, audiAcc, Target, act_n, 배급사]
# Index: []

# %%
df3['배급사'].value_counts()
# Out:
# (주)씨제이이엔엠                               182
# 유니버설픽쳐스인터내셔널 코리아(유)                     169
# (주)팝엔터테인먼트                              153
# 롯데쇼핑㈜롯데엔터테인먼트                           151
# (주)넥스트엔터테인먼트월드(NEW)                     147
#                                        ...
# (주)갤럭시컴퍼니                                 1
# (주)아이코닉스                                  1
# KBS 미디어                                   1
# (주)콘텐츠판다,(주)스마일이엔티                        1
# (주)대명문화공장,KT&G 상상마당 영화사업팀 컴퍼니에스에스(주)      1
# Name: 배급사, Length: 802, dtype: int64

# %%
df3['배급사'] = df3['배급사'].str.replace('㈜','')

# %%
def get_dis(x) :
    if 'CJ' in x or 'CGV' in x or '씨제이' in x :
        return 'CJ'
    elif '쇼박스' in x :
        return '쇼박스'
    elif 'SK' in x or '에스케이' in x:
        return 'SK'
    elif '리틀빅픽' in x :
        return '리틀빅픽처스'
    elif '스폰지' in x :
        return '스폰지'
    elif '싸이더스' in x :
        return '싸이더스'
    elif '에이원' in x :
        return '에이원'
    elif '마인스' in x :
        return '마인스'
    elif '마운틴픽' in x :
        return '마운틴픽처스'
    elif '디씨드' in x :
        return '디씨드'
    elif '드림팩트' in x :
        return '드림팩트'
    elif '메가박스' in x :
        return '메가박스'
    elif '마운틴' in x :
        return '마운틴'
    elif '롯데' in x :
        return '롯데'
    elif 'KBS' in x :
        return 'KBS'
    elif '제이앤씨미디어그룹' in x :
        return '제이앤씨미디어그룹'
    elif '월트디즈니' in x :
        return '월트디즈니'
    elif '그린나래' in x :
        return '그린나래'
    elif 'KTG상상마당' in x or 'KT'in x :
        return 'KTG상상마당'
    elif 'TJOY' in x or 'T-JOY' in x:
        return 'TJOY'
    elif '디오시네마' in x :
        return '디오시네마'
    elif '스톰픽쳐스' in x :
        return '스톰픽쳐스'
    elif '디스테이션' in x :
        return '디스테이션'
    elif '더블앤조이' in x :
        return '디스테이션'
    elif 'CBS' in x :
        return 'CBS'
    elif 'CBS' in x :
        return 'CBS'
    elif '더쿱' in x :
        return '더쿱'
    elif '더콘텐츠온' in x :
        return '더콘텐츠온'
    elif '소니픽쳐스' in x :
        return '소니픽쳐스'
    elif '이수' in x :
        return '이수'
    elif '워너' in x :
        return '워너브라더스'
    elif '삼백' in x :
        return '삼백상회'
    elif '폭스' in x :
        return '폭스코리아'
    elif '엣나인' in x :
        return '엣나인필름'
    elif '티캐스트' in x :
        return '티캐스트'
    elif '콘텐츠판다' in x :
        return '콘텐츠판다'
    elif '판씨네마' in x :
        return '판씨네마'
    elif '키다리' in x :
        return '키다리이엔티'
    elif '스마일이' in x :
        return '스마일이엔티'
    elif '팝엔' in x :
        return '팝엔터테인먼트' 
    elif '오퍼스' in x :
        return '오퍼스픽쳐스' 
    elif '와이드' in x :
        return '와이드릴리즈' 
    elif '오드' in x :
        return '오드' 
    elif '조이앤' in x :
        return '조이앤시네마' 
    elif '박수' in x :
        return '박수엔터테인먼트' 
    elif '찬란' in x :
        return '찬란'
    elif '얼리' in x :
        return '얼리버드'
    elif '영화사빅' in x :
        return '영화사빅'
    elif '에이스' in x :
        return '에이스메이커'
    elif '퍼스트런' in x :
        return '퍼스트런'
    elif 'MM' in x or 'M&M' in x:
        return 'MM인터내셔널'
    elif '드림웨스트' in x :
        return '드림웨스트픽쳐스'
    elif '홀리가든' in x :
        return '홀리가든'
    elif 'R&R' in x :
        return 'RR프로덕션'
    elif '머스트' in x :
        return '머스트씨무비'
    elif '블룸즈' in x :
        return '블룸즈베리'
    elif '모쿠' in x :
        return '모쿠슈라'
    elif '니버설' in x :
        return '유니버설픽쳐스'
    elif '시네마달' in x :
        return '시네마달'
    else :
        return x

# %%
df3['배급사'] = df3['배급사'].apply(get_dis)

# %%
df3['배급사'].nunique() #467
# Out:
# 542

# %%
# 상위 100개의 배급사를 제외하고 '기타'로처리
df3['배급사'].value_counts()[:100]
# Out:
# CJ                     328
# 롯데                     206
# 팝엔터테인먼트                173
# 유니버설픽쳐스                169
# (주)넥스트엔터테인먼트월드(NEW)    147
#                       ...
# 더콘텐츠온                   15
# (주)엔케이컨텐츠               14
# (주)키노아이디엠씨              14
# (주)제이에이와이이엔터테인먼트        13
# (주)시너지하우스 (시너지)         13
# Name: 배급사, Length: 100, dtype: int64

# %%
distributor_list = df3['배급사'].value_counts()[:100]
def func(distributor):
    if distributor in distributor_list:
        return distributor
    else:
        return '기타'

# %%
df3['배급사'] = df3['배급사'].apply(lambda x : func(x))

# %%
# 배급사별 영화 관객수 중위값 기준으로 배급사 랭크 인코딩
tr_dist_rank =df3.groupby('배급사').audiAcc.median().reset_index(name = 'dist_rank').sort_values(by = 'dist_rank',ascending=False)
tr_dist_rank
# Out:
#             배급사  dist_rank
# 61          쇼박스  1144894.0
# 79        월트디즈니   901534.0
# 98        폭스코리아   576861.5
# 78       워너브라더스   527331.0
# 60        소니픽쳐스   462514.0
# ..          ...        ...
# 22  (주)영화사 안다미로        1.0
# 18  (주)영진크리에이티브        1.0
# 12   (주)시네마리퍼블릭        1.0
# 4   (주)도키엔터테인먼트        1.0
# 50      라온아이(주)        1.0
#
# [101 rows x 2 columns]

# %%
tr_dist_rank['dist_rank'] = [i + 1 for i in range(tr_dist_rank.shape[0])]
tr_dist_rank
# Out:
#             배급사  dist_rank
# 61          쇼박스          1
# 79        월트디즈니          2
# 98        폭스코리아          3
# 78       워너브라더스          4
# 60        소니픽쳐스          5
# ..          ...        ...
# 22  (주)영화사 안다미로         97
# 18  (주)영진크리에이티브         98
# 12   (주)시네마리퍼블릭         99
# 4   (주)도키엔터테인먼트        100
# 50      라온아이(주)        101
#
# [101 rows x 2 columns]

# %%
df3 = pd.merge(df3, tr_dist_rank, how = 'left')

# %%
df3
# Out:
#                 title  directors  \
# 0     스왈로 탐험대와 아마존 해적    필립파 로소프
# 1                  물괴        허종호
# 2               싱글라이더        이주영
# 3             리즈와 파랑새    야마다 나오코
# 4               레드 후드     르네 페르즈
# ...               ...        ...
# 6376            파라노이아    로버트 루케틱
# 6377         춘하추동 로맨스        오창민
# 6378          4명의 암살자  스텐리 J. 오젤
# 6379             변종샤크    그리프 퍼스트
# 6380            터널 3D        박규택
#
#                                                  actors   genre        등급  \
# 0               켈리 맥도날드, 앤드류 스캇, 라페 스펠, 해리 엔필드, 제시카 하인즈    어드벤처     전체관람가
# 1     김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...      액션  15세이상관람가
# 2     이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...     드라마  15세이상관람가
# 3            타네자키 아츠미, 토야마 나오, 혼다 미유, 후지무라 코노미, 야마오카 유리   애니메이션     전체관람가
# 4          로버트 앰슬러, 니콜 스탁, 로버트 S. 딕슨, 콜린 허시, 제이슨 제이 프라도     판타지  15세이상관람가
# ...                                                 ...     ...       ...
# ...

# %% [markdown]
# ## 장르 전처리

# %%
df3[df3['genre']=='기타']
# Out:
#                   title                directors  \
# 257                십팔나한                      심화신
# 403         무림9대문파-호골매화                      저우시
# 490             잊지 않았어요                      박용철
# 502      브링 더 소울 : 더 무비                      박준수
# 724            디재스터 라이프                      백지훈
# 823           마음에 부는 바람                      윤석호
# 833      번 더 스테이지: 더 무비                      박준수
# 1638           방 안의 코끼리            박수영, 권칠인, 권호영
# 1661            살인의 기억법                     존 키스
# 1824               수필러브                      홍두표
# 1847           식물카페, 온정                      최창환
# 1999             마지막 휴가                      노거경
# 2148              인트로덕션                      홍상수
# 2169           잃어버린 아이들                      팽삼원
# 2193            구라, 베토벤                       봉수
# 2386            시크릿 카운터                   아라키 신지
# 2487       데드락: 라스트 리벤지                    자레드 콘
# 2535     네가 내가 되었으면 좋겠다                      김충길
# ...

# %%
df3.at[257, 'genre'] = '액션'
df3.at[403, 'genre'] = '액션'
df3.at[490, 'genre'] = '드라마'
df3.at[502, 'genre'] = '공연'
df3.at[724, 'genre'] = '코미디'
df3.at[823, 'genre'] = '멜로/로맨스'
df3.at[833, 'genre'] = '공연'
df3.at[1638, 'genre'] = '코미디'
df3.at[1661, 'genre'] = '스릴러'

df3.at[1824, 'genre'] = '다큐멘터리'
df3.at[1847, 'genre'] = '드라마'
df3.at[1999, 'genre'] = '드라마'
df3.at[2148, 'genre'] = '드라마'
df3.at[2169, 'genre'] = '드라마'
df3.at[2193, 'genre'] = '스릴러'
df3.at[2386, 'genre'] = '미스터리'
df3.at[2487, 'genre'] = '액션'
df3.at[2535, 'genre'] = '멜로/로맨스'

df3.at[2615, 'genre'] = '드라마'
df3.at[2846, 'genre'] = '드라마'
df3.at[3147, 'genre'] = '멜로/로맨스'
df3.at[3155, 'genre'] = '드라마'
df3.at[3170, 'genre'] = '드라마'
df3.at[3347, 'genre'] = '액션'
df3.at[3838, 'genre'] = '다큐멘터리'

# %%
df3[df3['genre']=='기타']
# Out:
# Empty DataFrame
# Columns: [title, directors, actors, genre, 등급, 개봉일, 국적, screenCnt, salesAcc, audiAcc, Target, act_n, 배급사, dist_rank]
# Index: []

# %%
df3.groupby('genre').audiAcc.mean().sort_values(ascending=False)
# Out:
# genre
# 사극          3.057790e+06
# 어드벤처        7.739510e+05
# 범죄          6.504936e+05
# 액션          6.049380e+05
# 판타지         4.488330e+05
# SF          3.163311e+05
# 코미디         3.075698e+05
# 애니메이션       2.521300e+05
# 미스터리        2.198196e+05
# 스릴러         2.174327e+05
# 드라마         2.031958e+05
# 전쟁          1.832081e+05
# 멜로/로맨스      1.523581e+05
# 서부극(웨스턴)    1.300725e+05
# 공포(호러)      1.166965e+05
# 가족          7.328789e+04
# 뮤지컬         5.278707e+04
# 다큐멘터리       2.695423e+04
# 공연          1.723972e+04
# Name: audiAcc, dtype: float64

# %%
df3['genre_rank'] = df3.genre.map({'공연' : 19, '다큐멘터리' : 18, '뮤지컬' : 17, '가족' : 16,
                                      '공포(호러)' : 15, '서부극(웨스턴)' : 14, '멜로/로맨스' : 13, '전쟁' : 12, '드라마' : 11, '스릴러' : 10, '미스터리' : 9, '애니메이션':8,'코미디':7,'SF':6,'판타지':5,'액션':4,'범죄':3,'어드벤처':2,'사극':1})

# %% [markdown]
# ## 등급 원핫

# %%
df3 = pd.get_dummies(columns = ['등급'], data = df3)

# %% [markdown]
# ## 국적 전처리

# %%
df3['국적'].unique()
# Out:
# array(['영국', '한국', '일본', '미국', '캐나다', '스페인', '프랑스', '이탈리아', '러시아', '대만',
#        '중국', '독일', '스웨덴', '아르헨티나', '벨기에', '터키', '말레이시아', '홍콩', '아일랜드',
#        '아이슬란드', '기타', '체코', '호주', '폴란드', '노르웨이', '마케도니아', '핀란드', '인도',
#        '브라질', '필리핀', '베네수엘라', '헝가리', '태국', '우크라이나', '이란', '멕시코', '덴마크',
#        '뉴질랜드', '칠레', '싱가포르', '네덜란드', '에스토니아', '그리스', '오스트리아', '페루',
#        '이스라엘', '팔레스타인', '스위스', '인도네시아', '불가리아', '슬로바키아', '모로코', '포르투갈',
#        '우즈베키스탄', '쿠바', '남아프리카공화국', '크로아티아', '루마니아', '세르비아', '우루과이', '베트남',
#        '카자흐스탄', '아랍에미리트연합국정부'], dtype=object)

# %%
df3[df3['국적']=='기타']
# Out:
#                    title            directors  \
# 159             엘리펀트킹 덤보             하디 모하메디안
# 185                더 리프트              데얀 제체비치
# 646                카잔자키스           야니스 스마라그디스
# 690             인비저블 라이프             카림 아이노우즈
# 738   스카이와 친구들: 로보시티의 비밀  아나톨리 보로디치, 루슬란 시바체프
# ...                  ...                  ...
# 5940                텔레비전        모스타파 사르와르 파루키
# 5952                 와즈다            하이파 알 만수르
# 5962              사라진 기억           크리스티나 부오지테
# 6027                드림빌더       킴 하겐 젠슨, 토니 징크
# 6266           모두의 천사 가디                아민 도라
#
#                                                  actors   genre         개봉일  \
# 159                             이인석, 안현서, 김정훈, 박민기, 김유림   애니메이션  2019-06-13
# 185   켄 포리, 카타리나 카스, 몬테 마크햄, 드라간 미카노비치, 데니스 무리치, 소냐 ...      SF  2018-12-12
# 646   오디세즈 파파스필리오풀로스, 마리나 칼로기루, 토도리스 아테리디스, 니코스 카르도니...     드라마  2020-01-30
# 690   줄리아 스토클러, 카롤 두아르테, 니콜라스 안투네스, 안토니오 폰세카, 그레고리오 ...     드라마  2020-06-24
# ...

# %%
df3.at[159, '국적'] = '이란'
df3.at[185, '국적'] = '세르비아'
df3.at[646, '국적'] = '그리스'
df3.at[690, '국적'] = '브라질'
df3.at[738, '국적'] = '벨라루스'

df3.at[839, '국적'] = '러시아'
df3.at[1196, '국적'] = '스리랑카'
df3.at[1793, '국적'] = '뉴질랜드'
df3.at[1821, '국적'] = '대만'
df3.at[1823, '국적'] = '덴마크'
df3.at[1825, '국적'] = '프랑스'
df3.at[1826, '국적'] = '프랑스'
df3.at[1845, '국적'] = '부탄'
df3.at[1849, '국적'] = '터키'
df3.at[1854, '국적'] = '미국'

df3.at[1915, '국적'] = '대만'
df3.at[1978, '국적'] = '이탈리아'
df3.at[2016, '국적'] = '미국'
df3.at[2034, '국적'] = '노르웨이'
df3.at[2040, '국적'] = '대만'

df3.at[2120, '국적'] = '대만'
df3.at[2122, '국적'] = '이란'
df3.at[2147, '국적'] = '독일'
df3.at[2157, '국적'] = '스웨덴'
df3.at[2160, '국적'] = '노르웨이'

df3.at[2164, '국적'] = '영국'
df3.at[2169, '국적'] = '중국'
df3.at[2196, '국적'] = '아이스랜드'
df3.at[2233, '국적'] = '체코'
df3.at[2260, '국적'] = '미국'
df3.at[2290, '국적'] = '노르웨이'

df3.at[2294, '국적'] = '멕시코'
df3.at[2300, '국적'] = '대만'
df3.at[2327, '국적'] = '튀니지'
df3.at[2343, '국적'] = '그리스'
df3.at[2377, '국적'] = '스웨덴'

df3.at[2410, '국적'] = '터키'
df3.at[2440, '국적'] = '스웨덴'
df3.at[2466, '국적'] = '모로코'
df3.at[2468, '국적'] = '핀란드'
df3.at[2477, '국적'] = '영국'

df3.at[2486, '국적'] = '핀란드'
df3.at[2537, '국적'] = '덴마크'
df3.at[2615, '국적'] = '노르웨이'
df3.at[2744, '국적'] = '프랑스'
df3.at[2820, '국적'] = '세르비아'

df3.at[2828, '국적'] = '노르웨이'
df3.at[2901, '국적'] = '에스토니아'
df3.at[2910, '국적'] = '파키스탄'
df3.at[3030, '국적'] = '벨기에'
df3.at[3065, '국적'] = '미국'

df3.at[3158, '국적'] = '뉴질랜드'
df3.at[3161, '국적'] = '노르웨이'
df3.at[3247, '국적'] = '태국'
df3.at[3385, '국적'] = '레바논'
df3.at[4145, '국적'] = '그린랜드'

df3.at[4289, '국적'] = '튀니지'
df3.at[4344, '국적'] = '노르웨이'
df3.at[4365, '국적'] = '인도'
df3.at[5537, '국적'] = '터키'
df3.at[5940, '국적'] = '방글라데시'

df3.at[5952, '국적'] = '사우디아라비아'
df3.at[5962, '국적'] = '리투아니아'
df3.at[6027, '국적'] = '덴마크'
df3.at[6266, '국적'] = '레바논'

# %%
df3[df3['국적']=='기타']
# Out:
# Empty DataFrame
# Columns: [title, directors, actors, genre, 개봉일, 국적, screenCnt, salesAcc, audiAcc, Target, act_n, 배급사, dist_rank, genre_rank, 등급_12세관람가, 등급_12세이상관람가, 등급_15세이상관람가, 등급_전체관람가, 등급_청소년관람불가]
# Index: []

# %%
# 상위 29개의 배급사를 제외하고 '기타'로처리
df3['국적'].value_counts()[:29]
# Out:
# 미국      1944
# 한국      1913
# 일본       558
# 프랑스      353
# 영국       333
# 중국       226
# 독일       143
# 캐나다      113
# 스페인       91
# 러시아       72
# 이탈리아      72
# 홍콩        66
# 호주        52
# 덴마크       35
# 대만        33
# 노르웨이      32
# 인도        28
# 멕시코       21
# 스웨덴       20
# 헝가리       19
# 태국        18
# 벨기에       18
# 아일랜드      17
# 폴란드       16
# 네덜란드      16
# 브라질       13
# 터키        12
# 핀란드       11
# 이스라엘      10
# Name: 국적, dtype: int64

# %%
contry_list = df3['국적'].value_counts()[:29]
def cont_func(contry):
    if contry in contry_list:
        return contry
    else:
        return '기타'

# %%
df3['국적'] = df3['국적'].apply(lambda x : cont_func(x))

# %%
tr_cont_rank = df3.groupby('국적').audiAcc.mean().reset_index(name = 'cont_rank').sort_values(by = 'cont_rank', ascending=False)
tr_cont_rank
# Out:
#       국적      cont_rank
# 26    한국  536512.555149
# 8     미국  394970.721708
# 9    벨기에  104575.111111
# 13  아일랜드   62206.352941
# 14    영국   55715.525526
# 18    일본   47015.974910
# 25   핀란드   42511.454545
# 17    인도   40161.500000
# 3     대만   38557.303030
# 12   스페인   31126.065934
# 24   프랑스   26312.473088
# 11   스웨덴   23843.650000
# 5     독일   21537.139860
# 4    덴마크   21110.314286
# 6    러시아   16306.138889
# 19    중국   14679.243363
# 28    호주   13383.788462
# 0     기타   13025.722222
# 16  이탈리아   11299.888889
# 29    홍콩   10029.075758
# 27   헝가리   10014.210526
# 7    멕시코    9814.380952
# 21    태국    9399.500000
# 20   캐나다    9136.566372
# 2   노르웨이    5034.250000
# 15  이스라엘    4876.300000
# 23   폴란드    4692.312500
# 1   네덜란드    4478.375000
# 10   브라질    3609.692308
# 22    터키    3526.833333

# %%
tr_cont_rank['cont_rank'] = [i + 1 for i in range(tr_cont_rank.shape[0])]
tr_cont_rank
# Out:
#       국적  cont_rank
# 26    한국          1
# 8     미국          2
# 9    벨기에          3
# 13  아일랜드          4
# 14    영국          5
# 18    일본          6
# 25   핀란드          7
# 17    인도          8
# 3     대만          9
# 12   스페인         10
# 24   프랑스         11
# 11   스웨덴         12
# 5     독일         13
# 4    덴마크         14
# 6    러시아         15
# 19    중국         16
# 28    호주         17
# 0     기타         18
# 16  이탈리아         19
# 29    홍콩         20
# 27   헝가리         21
# 7    멕시코         22
# 21    태국         23
# 20   캐나다         24
# 2   노르웨이         25
# 15  이스라엘         26
# 23   폴란드         27
# 1   네덜란드         28
# 10   브라질         29
# 22    터키         30

# %%
df3= pd.merge(df3, tr_cont_rank, how = 'left')
df3
# Out:
#                 title  directors  \
# 0     스왈로 탐험대와 아마존 해적    필립파 로소프
# 1                  물괴        허종호
# 2               싱글라이더        이주영
# 3             리즈와 파랑새    야마다 나오코
# 4               레드 후드     르네 페르즈
# ...               ...        ...
# 6376            파라노이아    로버트 루케틱
# 6377         춘하추동 로맨스        오창민
# 6378          4명의 암살자  스텐리 J. 오젤
# 6379             변종샤크    그리프 퍼스트
# 6380            터널 3D        박규택
#
#                                                  actors   genre         개봉일  \
# 0               켈리 맥도날드, 앤드류 스캇, 라페 스펠, 해리 엔필드, 제시카 하인즈    어드벤처  2021-09-02
# 1     김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...      액션  2018-09-12
# 2     이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...     드라마  2017-02-22
# 3            타네자키 아츠미, 토야마 나오, 혼다 미유, 후지무라 코노미, 야마오카 유리   애니메이션  2018-10-09
# 4          로버트 앰슬러, 니콜 스탁, 로버트 S. 딕슨, 콜린 허시, 제이슨 제이 프라도     판타지  2018-11-11
# ...                                                 ...     ...         ...
# ...

# %% [markdown]
# ## 감독 전처리??

# %%
df3['directors'].nunique()
# Out:
# 4648

# %%
df3_fin = df3.drop(['title','actors','배급사','genre','국적','directors','개봉일','salesAcc','audiAcc'], axis=1)

# %%
df3_fin['act_n'] = df3_fin['act_n'].astype('int')
df3_fin['act_n'] = np.log1p(df3_fin['act_n']) #로그변환

# %%
df3_fin
# Out:
#       screenCnt  Target     act_n  dist_rank  genre_rank  등급_12세관람가  \
# 0             1      11  1.791759         27           2          0
# 1          1183      11  4.804021          7           4          0
# 2           576      11  3.931826          4          11          0
# 3           214      11  1.791759         43           8          0
# 4             1      11  1.791759         89           5          0
# ...         ...     ...       ...        ...         ...        ...
# 6376          1      11  1.791759         60          11          0
# 6377          5      11  2.079442         71           7          0
# 6378          2      11  1.386294         89           4          0
# 6379          5      11  1.098612         79           6          0
# 6380        264      11  4.442651         33          15          0
#
#       등급_12세이상관람가  등급_15세이상관람가  등급_전체관람가  등급_청소년관람불가  cont_rank
# 0               0            0         1           0          5
# ...

# %%
df3_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6381 entries, 0 to 6380
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   screenCnt    6381 non-null   int64
#  1   Target       6381 non-null   int64
#  2   act_n        6381 non-null   float64
#  3   dist_rank    6381 non-null   int64
#  4   genre_rank   6381 non-null   int64
#  5   등급_12세관람가    6381 non-null   uint8
#  6   등급_12세이상관람가  6381 non-null   uint8
#  7   등급_15세이상관람가  6381 non-null   uint8
#  8   등급_전체관람가     6381 non-null   uint8
#  9   등급_청소년관람불가   6381 non-null   uint8
#  10  cont_rank    6381 non-null   int64
# dtypes: float64(1), int64(5), uint8(5)
# memory usage: 380.1 KB

# %%
df3_fin.to_csv('movie_df_classification.csv', index=False)

# %% [markdown]
# ## 모델링

# %% [markdown]
# ### train_test_split

# %%
y = df3_fin['Target']
x = df3_fin.drop('Target', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=100)

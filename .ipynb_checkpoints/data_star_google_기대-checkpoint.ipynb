# %%
import pandas as pd

# %%
df = pd.read_csv('data_merge수정2.csv')

# %%
star = pd.read_csv('star_buzz_df_fin.csv')

# %%
expect = pd.read_csv('data_제작비_한국_기대지수.csv')

# %%
star
# Out:
#       star_buzz
# 0             0
# 1          1629
# 2           581
# 3            18
# 4             3
# ...         ...
# 6376         23
# 6377         23
# 6378          4
# 6379          2
# 6380        630
#
# [6381 rows x 1 columns]

# %%
df = pd.concat([df,star], axis=1 )

# %%
df1 = df.drop(['Unnamed: 0', 'directors', 'actors', 'plots', 'genre',
       'runtime', 'keywords', '등급', '개봉일', '국적', 'screenCnt', 'salesAcc',
       'audiAcc'], axis=1)

# %%
df1
# Out:
#                 title  star_buzz
# 0     스왈로 탐험대와 아마존 해적          0
# 1                  물괴       1629
# 2               싱글라이더        581
# 3             리즈와 파랑새         18
# 4               레드 후드          3
# ...               ...        ...
# 6376            파라노이아         23
# 6377         춘하추동 로맨스         23
# 6378          4명의 암살자          4
# 6379             변종샤크          2
# 6380            터널 3D        630
#
# [6381 rows x 2 columns]

# %%
expect
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570       방황하는 칼날       이정호
# 571         571          히말라야       이석훈
# 572         572           허삼관       하정우
# 573         573  해적: 바다로 간 산적       이석훈
# 574         574           숫호구       백승기
#
#                                                 actors  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...
# ..                                                 ...
# 570  정재영, 이성민, 서준영, 김대명, 김현, 이수빈, 이주승, 최상욱, 김지혁, 김홍...
# ...

# %%
df_star = pd.merge(expect, df1,how='left', on='title' )

# %%
df_star
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 570         570       방황하는 칼날       이정호
# 571         571          히말라야       이석훈
# 572         572           허삼관       하정우
# 573         573  해적: 바다로 간 산적       이석훈
# 574         574           숫호구       백승기
#
#                                                 actors  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...
# ..                                                 ...
# 570  정재영, 이성민, 서준영, 김대명, 김현, 이수빈, 이주승, 최상욱, 김지혁, 김홍...
# ...

# %%
df_1978 = df[df['title']=='1987']

# %%
df_1978
# Out:
#     Unnamed: 0 title directors  \
# 88          88  1987       장준환
#
#                                                actors  \
# 88  김윤석, 하정우, 유해진, 김태리, 박희순, 이희준, 설경구, 여진구, 강동원, 유...
#
#                                                 plots genre  runtime  \
# 88  “책상을 탁! 치니 억! 하고 죽었습니다”1987년 1월, 경찰 조사를 받던 스물두...   드라마      129
#
#                                              keywords        등급         개봉일  \
# 88  518민주화운동,국가폭력,1980년대,1987년,대학생,검사,시위,신문기자,안기부,...  15세이상관람가  2017-12-27
#
#     국적  screenCnt      salesAcc  audiAcc  star_buzz
# 88  한국       1299  5.816558e+10  7231638       1830

# %%
df_1 = pd.concat([df_star,df_1978], axis=0)

# %%
df_1
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 571         571          히말라야       이석훈
# 572         572           허삼관       하정우
# 573         573  해적: 바다로 간 산적       이석훈
# 574         574           숫호구       백승기
# 88           88          1987       장준환
#
#                                                 actors  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...
# ..                                                 ...
# 571  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...
# ...

# %%
df_1.loc[df_1['title']=='1987','네이버_기대지수'] = 13877

# %%
df_1
# Out:
#      Unnamed: 0         title directors  \
# 0             0            물괴       허종호
# 1             1         싱글라이더       이주영
# 2             2          허스토리       민규동
# 3             3           풀잎들       홍상수
# 4             4            영주       차성덕
# ..          ...           ...       ...
# 571         571          히말라야       이석훈
# 572         572           허삼관       하정우
# 573         573  해적: 바다로 간 산적       이석훈
# 574         574           숫호구       백승기
# 88           88          1987       장준환
#
#                                                 actors  \
# 0    김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...
# 1    이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...
# 2    김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...
# 3    김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...
# 4    김향기, 김호정, 유재명, 탕준상, 장혜진, 김용준, 강동윤, 박옥출, 현봉식, 전...
# ..                                                 ...
# 571  황정민, 정우, 조성하, 김인권, 라미란, 김원해, 이해영, 전배수, 정규수, 성병...
# ...

# %%
df_1.to_csv('data_star_기대.csv', index=False)

# %% [raw]
# ## list length

# %%
### Naver Developers - Open API
import urllib
# Open API 사용 요청
client_id = 'PG3kwbDlhgk80hJqt_Ob'
client_secret = 'fbMT9Q0JGb'


def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext

def search_title(title):
    encText = urllib.parse.quote(title)
    url = 'https://openapi.naver.com/v1/search/movie.json?display=100&query=' + encText
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        d = json.loads(response_body.decode('utf-8'))
        if (len(d['items']) > 0):
            return d['items']
        else:
            return None

    else:
        print("Error Code:" + rescode)

# %%
import requests

# %%
d = search_title('레드후드')

# %%
d
# Out:
# [{'title': '리틀 <b>레드</b> 리딩 <b>후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=205514',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/2055/205514_P01_140836.jpg',
#   'subtitle': 'Little Red Riding Hood',
#   'pubDate': '2021',
#   'director': '보이코 카네브|',
#   'actor': '',
#   'userRating': '0.00'},
#  {'title': '<b>레드</b> 라이딩 <b>후드</b> 리덱스',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164883',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1648/164883_P01_175358.jpg',
#   'subtitle': 'Red Riding Hood Redux',
#   'pubDate': '2017',
#   'director': '다니엘 제젤|',
#   'actor': '',
#   'userRating': '0.00'},
#  {'title': '<b>레드 후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=141221',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1412/141221_P01_113531.jpg',
#   'subtitle': 'Little Red Riding Hood',
#   'pubDate': '2016',
#   'director': '르네 페르즈|',
#   'actor': '로버트 앰슬러|니콜 스탁|로버트 S. 딕슨|',
#   'userRating': '0.00'},
#  {'title': '<b>레드</b> 라이딩 <b>후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=76451',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/0764/76451_P04_144854.jpg',
#   'subtitle': 'Red Riding Hood',
#   'pubDate': '2011',
#   'director': '캐서린 하드윅|',
#   'actor': '아만다 사이프리드|게리 올드만|',
#   'userRating': '7.02'},
#  {'title': '배트맨 - 언더 더 <b>레드 후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=77550',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/0775/77550_P03_163630.jpg',
#   'subtitle': 'Batman: Under The Red Hood',
#   'pubDate': '2010',
#   'director': '브랜던 비에티|',
#   'actor': '브루스 그린우드|젠슨 애클스|',
#   'userRating': '8.91'},
#  {'title': '페로즈: 더 와일드 <b>레드</b> 라이딩 <b>후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=84784',
#   'image': '',
#   'subtitle': 'Ferozz: The Wild Red Riding Hood',
#   'pubDate': '2010',
#   'director': '호르헤 몰리나|',
#   'actor': '데이아나 레그라|로베르토 페르도모|',
#   'userRating': '0.00'},
#  {'title': '빨간 모자',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=81791',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/0817/81791_P01_113354.jpg',
#   'subtitle': 'Little Red Riding Hood',
#   'pubDate': '1997',
#   'director': '데이빗 캐플란|',
#   'actor': '크리스티나 리치|티무어 부타센코브|',
#   'userRating': '0.00'},
#  {'title': '더 메리드 라이프 오브 리틀 <b>레드</b> 라이딩 <b>후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=125876',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1258/125876_P01_170203.jpg',
#   'subtitle': 'The Married Life Of Little Red Riding Hood(Farce)',
#   'pubDate': '1973',
#   'director': '즐라코 부렉|',
#   'actor': '',
#   'userRating': '0.00'},
#  {'title': '<b>레드</b> 핫 라이딩 <b>후드</b>',
#   'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=62786',
#   'image': '',
#   'subtitle': 'Red Hot Riding Hood',
#   'pubDate': '1943',
#   'director': '텍스 에이버리|',
#   'actor': '도스 버틀러|준 포레이|',
#   'userRating': '0.00'}]

# %%
for n in (range(len(d))):
    if d
    a = d[n]['director'] == '르네 페르즈|'
# Out:
# False
# False
# True
# False
# False
# False
# False
# False
# False

# %%
for n in (range(len(d))):
    if d[i]['director'][:-1] == data[data['title'] == f'{keyword}']['directors'].values:
        break
    movie = d[i]

# %%
movie
# Out:
# {'title': '리틀 <b>레드</b> 리딩 <b>후드</b>',
#  'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=205514',
#  'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/2055/205514_P01_140836.jpg',
#  'subtitle': 'Little Red Riding Hood',
#  'pubDate': '2021',
#  'director': '보이코 카네브|',
#  'actor': '',
#  'userRating': '0.00'}

# %%
d[0]['director']
# Out:
# '보이코 카네브|'

# %%
import pandas as pd
data = pd.read_csv("data_merge수정2.csv")
data.head(10)
# Out:
#    Unnamed: 0               title         directors  \
# 0           0     스왈로 탐험대와 아마존 해적           필립파 로소프
# 1           1                  물괴               허종호
# 2           2               싱글라이더               이주영
# 3           3             리즈와 파랑새           야마다 나오코
# 4           4               레드 후드            르네 페르즈
# 5           5                  툴리          제이슨 라이트먼
# 6           6                허스토리               민규동
# 7           7  스페이스 치킨: 마법 부적의 비밀  알렉스 오렐, 에두아르도 슐트
# 8           8                 풀잎들               홍상수
# 9           9              선종 무문관               윤용진
#
#                                               actors  \
# 0            켈리 맥도날드, 앤드류 스캇, 라페 스펠, 해리 엔필드, 제시카 하인즈
# 1  김명민, 김인권, 혜리, 최우식, 이경영, 박희순, 박성웅, 이도경, 김중희, 이규...
# 2  이병헌, 공효진, 안소희, 잭 캠벨, 양유진, 애니카 화이틀리, 케이 에크룬드, 백...
# 3         타네자키 아츠미, 토야마 나오, 혼다 미유, 후지무라 코노미, 야마오카 유리
# 4       로버트 앰슬러, 니콜 스탁, 로버트 S. 딕슨, 콜린 허시, 제이슨 제이 프라도
# 5          샤를리즈 테론, 맥켄지 데이비스, 마크 듀플래스, 론 리빙스턴, 엘피나 룩
# 6  김희애, 김해숙, 예수정, 문숙, 이용녀, 김선영, 김준한, 이유영, 이지하, 이용...
# 7                  류승곤, 이인석, 이명희, 안현서, 김유림, 김정훈, 신한호
# 8  김민희, 정진영, 기주봉, 서영화, 김새벽, 안재홍, 공민정, 안선영, 신석호, 김...
# 9  우상전, 고동업, 안홍진, 조용주, 송유담, 임대혁, 조석준, 강서희, 최민재, 손...
#
#                                                plots  genre  runtime  \
# 0  “스왈로 탐험대의 출항을 허가한다”존과 엄마 그리고 동생들은 엄마가 어려서 뛰놀던 ...   어드벤처       97
# 1  “인왕산에 흉악한 짐승이 나타나 사람을 해쳤다 하옵니다.그것을 두고 듣지도 보지도 ...     액션      105
# 2  그가 사라졌다그에게서 모든 것이 사라졌다증권회사의 지점장 강재훈(이병헌). 안정된 ...    드라마       97
# 3  “너에겐 날개가 있고, 끝없이 펼쳐진 하늘도 있어”  늘 혼자였던 ‘리즈’ 앞에 어...  애니메이션       90
# 4  편찮은 할머니를 위해 약을 구해 돌아가던 빨간 모자 소녀는 늑대 모습을 한 기사에게...    판타지       81
# 5  “아이만이 아니에요, 당신을 돌보러 왔어요”‘지금’의 ‘마를로’에게 찾아온 가장 소...    드라마       95
# 6   이겨야죠! 이겨야 할매들 분이 안풀리겠습니까? 1992~1998 6년의 기간, 2...    드라마      121
# 7  치키와 럭키, 꼬꼬 형제에게 지구의 운명이 달렸다!만사 태평하고 철이 없지만 축구 ...  애니메이션       78
# 8  커피집이 있을 것 같지 않은 골목 안으로 커피집이 있고 사람들이 커피집 안 여기저기...    드라마       66
# 9  하나의 깨달음을 얻기 위해 한 곳에 모인 다섯명의 수행승들.저마다의 사연으로 무문관...    드라마       82
#
#                                             keywords        등급         개봉일  \
# 0                               여름휴가,외딴섬,아이들,모험,소설원작     전체관람가  2021-09-02
# 1                              조선시대,전염병,괴물,시대극/사극,사투  15세이상관람가  2018-09-12
# 2                        기러기아빠,호주,오스트레일리아,반전,반전영화,동물  15세이상관람가  2017-02-22
# 3                     십대소녀,단짝친구,외톨이,고3,합주,졸업반,마지막 연주     전체관람가  2018-10-09
# 4                                   괴물,성에 갇힌 남녀,감옥탈출  15세이상관람가  2018-11-11
# 5                             산후우울증,육아 스트레스,유모,분열된자아  15세이상관람가  2018-11-22
# 6  종군위안부,위안부,일본군위안부피해자,실화바탕,재판,관부재판,정신대,정신대할머니,법정...  12세이상관람가  2018-06-27
# 7                               외계인침공,지구수호,용기,성실,모험가     전체관람가  2018-10-25
# 8        삶과죽음,타인의 삶,언행,부산국제영화제,베를린영화제,삶의굴레,삶의순환,삶의의미  15세이상관람가  2018-10-25
# 9                            승려,스님,산속수행,불교,불교영화,종교영화     전체관람가  2018-12-13
#
#     국적  screenCnt      salesAcc  audiAcc
# 0   영국          1  5.000000e+04       10
# 1   한국       1183  6.104165e+09   723414
# 2   한국        576  2.685519e+09   351276
# 3   일본        214  1.741404e+08    21153
# 4   미국          1  1.000000e+03        1
# 5  캐나다        161  3.024830e+08    37241
# 6   한국        696  2.521026e+09   336822
# 7   미국        273  1.248995e+08    18169
# 8   한국         54  6.032025e+07     7443
# 9   한국          3  2.502380e+07     3012

# %%
direct = data['directors']

# %%
df = data["title"]
df
# Out:
# 0       스왈로 탐험대와 아마존 해적
# 1                    물괴
# 2                 싱글라이더
# 3               리즈와 파랑새
# 4                 레드 후드
#              ...
# 6376              파라노이아
# 6377           춘하추동 로맨스
# 6378            4명의 암살자
# 6379               변종샤크
# 6380              터널 3D
# Name: title, Length: 6381, dtype: object

# %% [markdown]
# 각 영화의 고유 코드 가져오기

# %%
code_lst = []
title_lst = []

for i in df.index[:]: #4272
    keyword = df[i]
    m = search_title(keyword)
                
    try:
        for n in (range(len(m))):
            if m[n]['director'][:-1] == data[data['title'] == f'{keyword}']['directors'].values:
                break
        link = m[n]['link']
        spl = str(link).split("=")
        it = spl[1]
        code_lst.append(it)
        
        title1 = m[n]['title']
        #title = title1_tag[0]
        title_lst.append(title1)
    except:
        code_lst.append('nan')
        title_lst.append(keyword)

# %%
while 'nan' in code_lst:
    code_lst.remove('nan')

# %%
len(code_lst)
# Out:
# 6381

# %%
title_lst
# Out:
# ['<b>스왈로 탐험대와 아마존 해적</b>',
#  '<b>물괴</b>',
#  '<b>싱글라이더</b>',
#  '<b>리즈와 파랑새</b>',
#  '<b>레드 후드</b>',
#  '트리 오브 <b>툴리</b>',
#  '<b>허스토리</b>',
#  '<b>스페이스 치킨: 마법 부적의 비밀</b>',
#  '<b>풀잎들</b>',
#  '<b>선종 무문관</b>',
#  '<b>누구나 아는 비밀</b>',
#  '택시 5',
#  '<b>영주</b>',
#  '<b>여배우는 오늘도</b>',
#  '<b>늦여름</b>',
#  '<b>다영씨</b>',
#  '<b>트리트 미 라이크 파이어</b>',
#  '<b>에일리언 킬러</b>',
#  '<b>배드 사마리안</b>',
#  '<b>상류사회</b>',
#  '<b>어른도감</b>',
#  '<b>궁합</b>',
#  '<b>리틀 포레스트</b>',
#  '<b>레인보우: 나의 사랑</b>',
#  '<b>달밤체조 2015</b>',
#  '<b>마틸다: 황제의 연인</b>',
#  '<b>논-픽션</b>',
#  '<b>튼튼이의 모험</b>',
#  '<b>나츠메 우인장: 세상과 연을 맺다</b>',
#  '<b>엘리스의 50가지 그림자</b>',
#  '<b>해피 댄싱</b>',
#  '<b>작년 겨울, 너와 이별</b>',
#  '<b>핫 썸머 나이츠</b>',
#  '<b>아스트로: 우주전쟁</b>',
#  '<b>프리다의 그해 여름</b>',
#  '<b>모어 댄 블루</b>',
#  '<b>주먹왕 랄프 2: 인터넷 속으로</b>',
#  '<b>스키타이: 불멸의 전사</b>',
#  '<b>강한 칼: 도도견혈</b>',
#  '<b>미스터 스마일</b>',
#  '<b>아사코</b>',
#  '<b>출동! 소방관 샘: 외계인 대소동</b>',
#  '<b>사우스사이드 위드 유</b>',
#  '<b>맥베스</b>',
#  '<b>극장판 토미카 하이퍼레스큐 드라이브헤드</b>',
#  '<b>사랑, 스무살</b>',
#  '<b>카운터스</b>',
#  '<b>후드</b>',
#  '<b>테이크 미 홈</b>',
#  '<b>메모리즈</b>',
#  '<b>목격자</b>',
#  '<b>철의 심장을 가진 남자</b>',
#  '<b>스위밍 위드 맨</b>',
#  '<b>퓨쳐 월드</b>',
#  '<b>스텝 바이 스텝</b>',
#  "<b>스타박'스 다방</b>",
#  '<b>더 테이블</b>',
#  '저니 오브 스타즈 <b>인투</b> <b>더</b> 다크 <b>나잇</b>',
#  '<b>에스코바르</b>',
#  '<b>토이무비: 미래대모험</b>',
#  '<b>불량가족, 행복의 맛</b>',
#  '<b>에이리언 컨버전스</b>',
#  '<b>마녀</b> 2',
#  '<b>봄이가도</b>',
#  '<b>라이브 하드</b>',
#  '<b>이미그레이션 게임</b>',
#  '<b>적 그리스도의 날</b>',
#  '<b>나의 마지막 수트</b>',
#  '<b>셜록 놈즈</b>',
#  '<b>청춘빌라 살인사건</b>',
#  '<b>두 번째 여름, 두 번 다시 만날 수 없는 너</b>',
#  '<b>소녀, 하늘을 날다</b>!',
#  '<b>너의 췌장을 먹고 싶어</b>',
#  '<b>에그엔젤 코코밍: 두근두근 핼러윈 파티</b>',
#  '<b>당신의 부탁</b>',
#  '<b>노크: 초대받지 않은 손님</b>',
#  '<b>호밀밭의 반항아</b>',
#  '<b>콜보이</b>',
#  '<b>플래니테리엄</b>',
#  '더 <b>파이널리스트</b>',
#  '<b>피쉬 프렌즈: 알록이의 신기한 모험</b>',
#  '<b>내 친구 정일우</b>',
#  '<b>더 보이스</b> 오브 더 터틀',
#  '<b>작전명 비스트</b>',
#  '<b>이비자 언데드</b>',
#  '<b>이스케이프 플랜 2: 하데스</b>',
#  '<b>신 전래동화</b>',
#  '<b>인랑</b>',
#  '<b>1987</b>',
#  '<b>호스틸</b>',
#  '<b>미래의 미라이</b>',
#  '<b>양아치 느와르</b>',
#  '<b>누에치던 방</b>',
#  '<b>마라</b>',
#  '<b>캡틴 스터비</b>',
#  '<b>벽 속에 숨은 마법시계</b>',
#  '<b>필름스타 인 리버풀</b>',
#  '<b>퀴어영화 뷰티풀</b>',
#  '<b>악몽의 미드나잇</b>',
#  '<b>트라이아스기 월드: 잃어버린 세계</b>',
#  '<b>촉산 복마전</b>',
#  '<b>이탈리안 레이스</b>',
#  '<b>집의 시간들</b>',
#  '<b>소성리</b>',
#  '<b>광대 케인</b>',
#  '<b>베스와 베라</b>',
#  '<b>덕구</b>',
#  '증기선 <b>윌리</b>',
#  '<b>골든슬럼버</b>',
#  '<b>불한당: 나쁜 놈들의 세상</b>',
#  '<b>페르시안 커넥션</b>',
#  '<b>수성못</b>',
#  '<b>해피 엔드</b>',
#  '<b>범블비</b>',
#  '<b>행복의 나라</b>',
#  '<b>곰돌이 푸 다시 만나 행복해</b>',
#  '<b>트와이스랜드</b>',
#  '<b>너와 극장에서</b>',
#  '<b>얼라이브</b>',
#  '<b>브레이븐</b>',
#  '<b>버닝</b>',
#  '<b>액슬</b>',
#  '<b>고스트 소스 제로</b>',
#  '<b>덤보</b>',
#  '<b>직지코드</b>',
#  '<b>왓칭</b>',
#  '<b>너의 새는 노래할 수 있어</b>',
#  '<b>우주전쟁 2019</b> ',
#  '<b>빙봉협: 시공행자</b>',
#  '<b>킹 오브 프리즘 -샤이니 세븐 스타즈-</b> Ⅳ 루이x신x언노운',
#  '<b>파리 에듀케이션</b>',
#  '<b>나의 히어로 아카데미아 더 무비: 두 명의 히어로</b>',
#  '<b>7호실</b>',
#  '<b>퍼펙트 타겟</b>',
#  '<b>T-34</b>',
#  '<b>미스 스티븐스</b>',
#  '<b>아녜스가 말하는 바르다</b>',
#  '<b>파도치는 땅</b>',
#  '<b>마왕의 딸 이리샤</b>',
#  '<b>리벤지: 엄마의 분노</b>',
#  '<b>시니스터 스쿼드</b>',
#  '<b>타임 트랩 킬러</b>',
#  '<b>온워드: 단 하루의 기적</b>',
#  '<b>그것만이 내 세상</b>',
#  '<b>블랙 47</b>',
#  '<b>박열</b>',
#  '<b>무협: 강호수사대</b>',
#  '<b>칠드런 액트</b>',
#  '<b>마이펫의 이중생활2</b>',
#  '<b>재심</b>',
#  '<b>하트스톤</b>',
#  '<b>프랑켄슈타인</b>',
#  '<b>메가로돈: 거대 상어의 습격</b>',
#  '<b>컴, 투게더</b>',
#  '<b>마차 타고 고래고래</b>',
#  '<b>쎈서</b>',
#  '<b>웨스트 사이드 스토리</b>',
#  '<b>로마의 휴일</b>',
#  '<b>스마트 체이스</b>',
#  '<b>엘리펀트킹 덤보</b>',
#  '<b>야수대전</b>',
#  '<b>파이브 피트</b>',
#  '<b>채비</b>',
#  '<b>박물관이 진짜 살아있다</b>',
#  '<b>어둔 밤</b>',
#  '<b>굿바이 썸머</b>',
#  '<b>오션스: 문어구출대작전</b>',
#  '<b>도라에몽: 스탠바이미 2</b>',
#  '<b>미스터 앤 미스터 대디</b>',
#  '<b>화씨 11/9: 트럼프의 시대</b>',
#  '<b>사월의 끝</b>',
#  '<b>대지진: 엔드 오브 더 월드</b>',
#  '<b>지렁이</b>',
#  '<b>질투의 역사</b>',
#  '<b>범죄도시</b>',
#  '<b>길</b>',
#  '<b>그날, 바다</b>',
#  '<b>델타 보이즈</b>',
#  '<b>번개맨의 비밀</b>',
#  '<b>공포의 신생아실</b>',
#  '<b>드래곤볼 슈퍼: 브로리</b>',
#  '<b>시인 할매</b>',
#  '<b>이차크의 행복한 바이올린</b>',
#  '<b>카운트다운: 쇼크웨이브</b>',
#  '<b>욜로 유 온리 리브 원스</b>',
#  '<b>더 리프트</b>',
#  '<b>반드시 잡는다</b>',
#  '<b>어글리 돌</b>',
#  '<b>내 완벽한 남사친의 비밀</b>',
#  '<b>겨울밤에</b>',
#  '<b>일진</b> 나쁜녀석들',
#  '<b>린 온 피트</b>',
#  '<b>킨: 더 비기닝</b>',
#  '스티브 <b>맥퀸</b>: 킹 오브 쿨',
#  '<b>인피니티 포스 : 독수리오형제 최후의 심판</b>',
#  '<b>극장판 가면라이더 이그제이드: 트루 엔딩</b>',
#  '<b>홍콩 마스터 어벤져</b>',
#  '<b>네 얼간이와 장례식</b>',
#  '<b>미션 이스탄불4: 익스트림 데이</b>',
#  '<b>완벽한 타인</b>',
#  '<b>오아시스 세탁소</b>',
#  '<b>환절기</b>',
#  '<b>할로윈</b> 킬즈',
#  '<b>갈매기</b>',
#  '<b>콜드 워</b>',
#  '<b>옷코는 초등학생 사장님</b>!',
#  '<b>고질라: 킹 오브 몬스터</b>',
#  '<b>할아버지</b>와 <b>고양이</b>',
#  '<b>독전</b>',
#  '<b>신비한 동물들과 그린델왈드의 범죄</b>',
#  '<b>폴란드로 간 아이들</b>',
#  '<b>발리: 천상의 울림</b>',
#  '<b>봉이 김선달</b>',
#  '<b>메리 셸리: 프랑켄슈타인의 탄생</b>',
#  '<b>숨바꼭질</b>',
#  '<b>테이크 다운</b>',
#  '<b>리틀 포니 프린세스</b>',
#  '<b>피를 빠는 인형</b>',
#  '<b>영하의 바람</b>',
#  '<b>공포의 묘지</b>',
#  '<b>샤잠</b>!',
#  '<b>키코리키: 시간여행</b>',
#  '<b>모진: 용골천서의 비밀</b>',
#  '<b>다이노소어 월드</b>',
#  '<b>더 넌</b>',
#  '<b>용순</b>',
#  '<b>기억의 전쟁</b>',
#  '<b>한강에게</b>',
#  '<b>짱</b>',
#  '<b>리지</b>',
#  '<b>나의 작은 시인에게</b>',
#  '<b>아이아이 가사: 다시 만난 그날</b>',
#  '<b>파이널 포트레이트</b>',
#  '<b>극장판 진격의 거인 2기: 각성의 포효</b>',
#  '<b>프레데터 2018</b>',
#  '<b>라 멜로디</b>',
#  '<b>5.18 힌츠페터 스토리</b>',
#  '<b>밤쉘</b>',
#  '<b>원스 어폰 어 타임 인 베니스</b>',
#  '<b>신은 죽지 않았다 3: 어둠 속의 빛</b>',
#  '<b>파라독스</b>',
#  '<b>극장판 페어리 테일: 드래곤 크라이</b>',
#  '<b>꼬마영웅 바비</b>',
#  '<b>아이 캔 온리 이매진</b>',
#  '발트해(오들랜드, 세인트<b>루시</b>의 날)#16',
#  '<b>바르다가 사랑한 얼굴들</b>',
#  '<b>아이 필 프리티</b>',
#  '<b>친애하는 우리 아이</b>',
#  '<b>아기곰 보보 구출 대작전</b>',
#  '<b>레오나르도 다 빈치</b>',
#  '<b>28세 미성년</b>',
#  '<b>섹션제로3-블록13</b>',
#  '<b>미드나잇 선</b>',
#  '<b>쥬라기 월드: 폴른 킹덤</b>',
#  '<b>이름없는 새</b>',
#  '<b>벅스 프렌즈</b>',
#  '<b>빅 식</b>',
#  '<b>십팔나한</b>',
#  '<b>트립 투 스페인</b>',
#  '<b>오션스8</b>',
#  '<b>전설의 고향</b>',
#  '<b>극장판 포켓몬스터DP - 디아루가 VS 펄기아 VS 다크라이</b>',
#  '<b>드래곤 프린세스</b>',
#  '<b>딜레마</b>',
#  '<b>흥부: 글로 세상을 바꾼 자</b>',
#  '<b>실종: 비밀의 소녀</b>',
#  '<b>무곡</b>',
#  '<b>겨울왕국의 무민</b>',
#  '<b>해피 어게인</b>',
#  '<b>매드맥스: 로드 워</b>',
#  '<b>얼리맨</b>',
#  '<b>쿵푸몽키</b>',
#  '<b>섹션제로2-블랙스쿼드</b>',
#  '<b>열다섯의 순수</b>',
#  '<b>예스 평창</b>!',
#  '<b>식스 빌로우</b>',
#  '<b>템프팅</b> 피어',
#  '<b>포크레인</b>',
#  '<b>언더독</b> - 시리즈',
#  '내친구호비 극장판 <b>호비와 매직아일랜드</b>',
#  '<b>시카리오: 데이 오브 솔다도</b>',
#  '<b>잉글랜드 이즈 마인</b>',
#  '<b>빅샤크: 매직체인지</b>',
#  '<b>유니콘 원정대: 비밀의 다이어리</b>',
#  '락 시티',
#  '<b>유전</b>',
#  '<b>한 솔로: 스타워즈 스토리</b>',
#  '<b>류이치 사카모토: 코다</b>',
#  '<b>개들의 섬</b>',
#  '<b>배틀 드론</b>',
#  '<b>해원</b>',
#  '<b>애국청년 변희재</b>',
#  '<b>새엄마:강제섹스를 하다</b>',
#  '<b>콜 미 바이 유어 네임</b>',
#  '<b>톨 맨: 악마는 살아있다</b>',
#  '<b>메리와 마녀의 꽃</b>',
#  '<b>팩트 살인</b>',
#  '<b>다크쇼: 익스트림 서바이버</b>',
#  '<b>로드 투 로마</b>',
#  '<b>뮤지컬 홀리데이 인</b>',
#  '<b>밤은 짧아 걸어 아가씨야</b>',
#  '<b>신오오쿠보이야기:마이네임</b>',
#  '<b>쥬만지: 새로운 세계</b>',
#  '<b>섹션제로-3구역</b>',
#  '<b>유어 무브</b>',
#  '<b>팬텀 스레드</b>',
#  '<b>원더 휠</b>',
#  '<b>스페셜 시큐리티 : 라스트 미션</b>',
#  '<b>리노</b>',
#  '<b>렌델: 어둠의 기사</b>',
#  '<b>청년 마르크스</b>',
#  '<b>가족사진</b>',
#  '<b>스피벳:천재 발명가의 기묘한 여행</b>',
#  '<b>럭키 스티프</b>',
#  '<b>벤허: 레저렉션</b>',
#  '<b>다크송: 저주의 시작</b>',
#  '배트맨 대 슈퍼맨: <b>저스티스</b>의 시작',
#  '감성여행 - 내 <b>22</b>번째 프로젝트',
#  '<b>바울</b>',
#  '<b>다키스트 아워</b>',
#  '<b>지구: 놀라운 하루</b>',
#  '<b>사라진 밤</b>',
#  '<b>핀두스 이야기</b>',
#  '<b>사촌누나와 동거</b>',
#  '<b>엔티티 블레이드</b>',
#  '<b>피터 래빗</b> 2: 파 프롬 가든',
#  '<b>더 펜션</b>',
#  '<b>프렌치 커넥션: 마약수사</b>',
#  '<b>라라</b>',
#  '<b>50가지 그림자: 해방</b>',
#  '<b>데드풀 2</b>',
#  '<b>에이리언 지구대침공</b>',
#  '<b>50가지 욕망의 그림자</b>',
#  '<b>시간위의 집 디 오리지널</b>',
#  '라 당스',
#  '<b>테이큰: 미녀들의 전쟁</b>',
#  '<b>쿵푸 크로니클</b>',
#  '<b>막달라 마리아: 부활의 증인</b>',
#  '<b>토마스와 친구들: 그레이트 레이스</b>',
#  '<b>레드 스패로</b>',
#  '<b>타임 투게더</b>',
#  '<b>국경의 왕</b>',
#  '<b>팜스윙스 스와핑클럽</b>',
#  '<b>몰리스 게임</b>',
#  '<b>톰보이리벤저</b>',
#  '<b>페이트 스테이 나이트 헤븐즈필 제1장 프레시지 플라워</b>',
#  '<b>허리케인 하이스트</b>',
#  '<b>바라나시</b>',
#  '<b>할로우 차일드</b>',
#  '<b>꼬마 보트 토토: 타요 타요 배 타요</b>',
#  '<b>강변호텔</b>',
#  '<b>킬링 군터</b>',
#  '<b>더 바이 바이 맨</b>',
#  '<b>라이프 필스 굿</b>',
#  '<b>플로이</b>',
#  '<b>어느 가족</b>',
#  '<b>라이즈 위 텔</b>',
#  '<b>사이드 이펙트</b>',
#  '<b>인크레더블 2</b>',
#  '<b>데스트랩</b>',
#  '<b>알리바이 닷 컴</b>',
#  '<b>새벽의 약속</b>',
#  '<b>바니부기: 드래곤 에그를 찾아서</b>',
#  '<b>언덕길의 아폴론</b>',
#  '<b>몬스터</b> 랜드',
#  '<b>액츠 오브 바이올런스</b>',
#  '<b>스카이스크래퍼</b>',
#  '<b>노 맨스 랜드</b>',
#  '<b>메가로돈</b>',
#  '<b>필동</b>',
#  '<b>휘트니</b> 커머셜',
#  '<b>나를 차버린 스파이</b>',
#  '<b>메가 샤크 어택</b>',
#  '<b>컨저링</b> : <b>마녀</b>의 <b>인형</b>',
#  '<b>게스트</b> 인 <b>더</b> 하우스',
#  '<b>체실 비치에서</b>',
#  '<b>타샤 튜더</b>',
#  '<b>픽시</b> 잇츠 워터멜론',
#  '<b>나미야 잡화점의 기적: 또 하나의 이야기</b>',
#  '<b>카르멘</b>',
#  '<b>에브리데이</b>',
#  '<b>서치</b>',
#  '<b>루나: 소녀의 복수</b>',
#  '<b>더 프레데터</b>',
#  '<b>해적왕 작스톰</b>',
#  '<b>위스키 밴디트</b>',
#  '<b>몬스터 호텔 3</b>',
#  '<b>지오 쓰나미</b>',
#  '<b>박화영</b>',
#  '<b>환생령</b>',
#  '극장판 <b>레이디버그</b>: 미라클스톤의 비밀',
#  '<b>혈랑: 붉은전사</b>',
#  '<b>펭귄 하이웨이</b>',
#  '<b>오목소녀</b>',
#  '<b>어드리프트:우리가 함께한 바다</b>',
#  '<b>카메라를 멈추면 안 돼</b>!',
#  '<b>데스 위시</b>',
#  '<b>갱 브라더스: 마지막 대결</b>',
#  '<b>세일즈맨의 전설</b>',
#  '<b>양말요정 휴고의 대모험</b>',
#  '<b>죽음의 리무진</b>',
#  '<b>더 크리미널 마인드: 공공의 적</b>',
#  '<b>비트윈 랜드 앤 씨</b>',
#  '<b>무림9대문파-호골매화</b>',
#  '<b>극장판 레이디버그: 미라클스톤의 비밀</b>',
#  '<b>마야2</b>',
#  '<b>중2병이라도 사랑이 하고 싶어! 테이크 온 미</b>',
#  '<b>호박과 마요네즈</b>',
#  '<b>아기돼지 3형제와 쿵푸랜드</b>',
#  '<b>부르고뉴, 와인에서 찾은 인생</b>',
#  '<b>토스카</b>',
#  '<b>창궐</b>',
#  '<b>패왕화 스페셜 포스</b>',
#  '<b>영혼의 순례길</b>',
#  '빅 <b>샷 콜러</b>',
#  '<b>극장판 뚝딱뚝딱 밥아저씨: 메가 머신의 역습</b>',
#  '<b>더 로저스</b>',
#  '<b>스페셜 스쿼드</b>',
#  '<b>방콕 크리미널</b>',
#  '<b>레전드 워리어</b>',
#  '<b>맨헌트</b>',
#  '<b>베러 와치 아웃</b>',
#  '<b>젝스키스 에이틴</b>',
#  '<b>플라야</b> <b>델</b> 푸투로',
#  '<b>안녕, 나의 소녀</b>',
#  '<b>뷰티풀 투모로우</b>',
#  '<b>마징가 Z: 인피니티</b>',
#  '<b>험악한 꿈</b>',
#  '<b>앤트로포이드</b>',
#  '<b>인시디어스4: 라스트 키</b>',
#  '<b>아이다</b>',
#  '<b>한낮의 유성</b>',
#  '<b>그녀의 인생은 잘못이 없어</b>',
#  '<b>헤밍웨이 인 하바나</b>',
#  '<b>라스트 솔져스 : 최후의 결전</b>',
#  '<b>추룡</b>',
#  '<b>톰 오브 핀란드</b>',
#  '<b>좋아하지도 않으면서</b>',
#  '<b>극장판 도라에몽: 진구의 보물섬</b>',
#  '<b>마일 22</b>',
#  '<b>원초적 비디오 테이프</b>',
#  '<b>그린치</b>는 어떻게 크리스마스를 훔쳤는가!',
#  '<b>극장판 헬로카봇 : 백악기 시대</b>',
#  '<b>명탐정 코난 : 제로의 집행인</b>',
#  '<b>논스톱: 다마스커스 타겟</b>',
#  '<b>안나, 평양에서 영화를 배우다</b>',
#  '<b>미션 임파서블: 폴아웃</b>',
#  '<b>인 더 더스트</b>',
#  '<b>대관람차</b>',
#  '<b>루나</b>',
#  '<b>하나 빼고 완벽한 뉴욕 아파트</b>',
#  '<b>타지마할</b> <b>호텔</b>로의 귀환',
#  '<b>업그레이드</b>',
#  '<b>리:본</b>',
#  '<b>이별의 아침에 약속의 꽃을 장식하자</b>',
#  '<b>앤트맨과 와스프</b>',
#  '<b>호텔 아르테미스</b>',
#  '<b>펠리니를 찾아서</b>',
#  '<b>요묘전: 레전드 오브 더 데몬 캣</b>',
#  '<b>허리케인 샤크네이도</b>',
#  '<b>뷰티풀 뱀파이어</b>',
#  '<b>인투 더 샤크스톰</b>',
#  '<b>빅 스코어</b>',
#  '<b>몬스터</b>',
#  '<b>맨 인 블랙: 인터내셔널</b>',
#  '<b>더 보이</b>',
#  '<b>극한직업</b>',
#  '<b>희생부활자</b>',
#  '<b>크레이지 버그</b>',
#  '<b>극장판 포켓몬스터 모두의 이야기</b>',
#  '<b>얼굴없는 보스</b> : 못다한 이야기 감독판',
#  '<b>머피와 샐리의 법칙</b>',
#  '<b>굿 라이어</b>',
#  '<b>무림3대고수전</b>',
#  '<b>워파이터</b>',
#  '<b>악마의 오후</b>',
#  '<b>체크 히어로</b>',
#  '<b>킹 다닐로</b>',
#  '<b>사일런스</b>',
#  '<b>스크림: 허수아비의 저주</b>',
#  '<b>이웃집 스타</b>',
#  '<b>콰이어트 플레이스 2</b>',
#  '<b>파티 크래셔</b>',
#  '<b>나이브스 아웃</b> 2',
#  '<b>디터 람스</b>',
#  '<b>수상한 교수</b>',
#  '<b>아픈 만큼 사랑한다</b>',
#  '<b>디에고</b>',
#  '<b>외계인 지구침공</b>',
#  '<b>새벽의 저주: 악령의 부활</b>',
#  '<b>잊지 않았어요</b>',
#  '<b>극장판 엉덩이 탐정: 화려한 사건 수첩</b>',
#  '<b>알라딘-램프의 신</b>',
#  '<b>왕이 될 아이</b>',
#  '<b>발명왕 볼트</b>',
#  '<b>명탐정 코난: 감청의 권</b>',
#  '<b>메리 포핀스 리턴즈</b>',
#  '<b>김광석</b>',
#  '<b>월드 워 핵전쟁의 서막</b>',
#  '<b>오멘 666</b>',
#  '<b>60일의 썸머</b>',
#  '<b>컨저링 맨션</b>',
#  '<b>브링 더 소울 : 더 무비</b>',
#  '<b>디아블로: 분노의 질주</b>',
#  '<b>크롤</b>',
#  '<b>신문기자</b>',
#  '<b>데드 바이 데이라이트</b>',
#  '온 <b>더 플랫폼</b>',
#  '<b>82년생 김지영</b>',
#  '<b>플레이모빌: 더 무비</b>',
#  '<b>두 번째 겨울</b>',
#  '<b>이스케이프 게임</b>',
#  '<b>악몽</b>',
#  '<b>10 바이 10</b>',
#  '나이트 오브 <b>더</b> 블러드 <b>비스트</b>',
#  '<b>시민 노무현</b>',
#  '<b>유랑지구</b>',
#  '<b>48시간: 지구 최후의 날</b>',
#  '<b>얼론 위 파이트</b>',
#  '<b>레토</b>',
#  '드라마 페스티벌 - 잠자는 <b>숲속</b>의 <b>마녀</b>',
#  '<b>바디 브로큰</b>',
#  '<b>체이싱</b>',
#  '<b>카오산 탱고</b>',
#  '<b>보희와 녹양</b>',
#  '<b>마녀: 소녀의 비밀</b>',
#  '<b>암드</b>',
#  '<b>신 복수무정</b>',
#  '<b>파리의 딜릴리</b>',
#  '<b>여중생A</b>',
#  '<b>그 누구도 아닌</b>',
#  '굿나잇 포 저스티스: <b>퀸 오브 하츠</b>',
#  '<b>칠곡 가시나들</b>',
#  '<b>토마스와 친구들: 우정의 대모험</b>',
#  '<b>부탁 하나만 들어줘</b>',
#  '<b>너의 결혼식</b>',
#  '<b>천하비급</b>',
#  '<b>베를린, 아이 러브 유</b>',
#  '<b>나의 청춘은 너의 것</b>',
#  '<b>트랜짓</b>',
#  '<b>재키</b>',
#  '<b>인어전설</b>',
#  '<b>군산: 거위를 노래하다</b>',
#  '<b>유령선</b>',
#  '<b>마피아</b>',
#  '<b>400: 제국의 부활</b>',
#  '<b>콜드플레이: 헤드 풀 오브 드림스</b>',
#  '<b>신 배틀로얄:극악 소년원2</b>',
#  '<b>아스테릭스: 마법 물약의 비밀</b>',
#  '티<b>타임</b>: 어 맨 오브 익스페리언스',
#  '<b>내가 사는 세상</b>',
#  '<b>요코하마 갱스터</b>',
#  '<b>닥치고 피아노</b>!',
#  '<b>엔젤 오브 마인</b>',
#  '<b>일일시호일</b>',
#  '<b>우리는 썰매를 탄다</b>',
#  '<b>호두까기 인형과 4개의 왕국</b>',
#  '<b>레이니 데이 인 뉴욕</b>',
#  '<b>라스트 크리스마스</b>',
#  '<b>엄마 바람피게하기</b>',
#  '<b>캡틴 마블</b>의 모험',
#  '<b>부니베어: 원시시대 대모험</b>',
#  '<b>루프홀</b>',
#  '<b>리암 갤러거</b>',
#  '<b>우리가족: 라멘샵</b>',
#  '<b>캣츠</b>',
#  '<b>소림절세귀동 - 천하곡술</b>',
#  '<b>뷰티풀 데이즈</b>',
#  '<b>소피와 드래곤: 마법책의 비밀</b>',
#  '<b>호랑이보다 무서운 겨울손님</b>',
#  '<b>윤희에게</b>',
#  '<b>10년</b>의 셀프 초상',
#  '<b>더 와이프</b>',
#  '<b>태양을 덮다</b>',
#  '<b>엑시트</b>',
#  '<b>벤트: 마약의 도시</b>',
#  '<b>터미네이터: 다크 페이트</b>',
#  '<b>데자뷰</b>',
#  '<b>로지</b>',
#  '<b>툼 인베이더</b>',
#  '<b>조선명탐정: 흡혈괴마의 비밀</b>',
#  '<b>레슬러</b>',
#  '<b>리틀 큐</b>',
#  '<b>저니스 엔드</b>',
#  '<b>온다</b>',
#  '<b>동화</b>',
#  '<b>더 컨덕터</b>',
#  '<b>가을 우체국</b>',
#  '<b>인크레더블 손오공</b>',
#  '<b>출동! 도토리 구조대</b>',
#  '<b>펠리칸 베이커리</b>',
#  '<b>찬실이는 복도 많지</b>',
#  '<b>임신한 나무와 도깨비</b>',
#  '<b>용길이네 곱창집</b>',
#  '<b>47미터 2</b>',
#  '<b>불빛 아래서</b>',
#  '<b>문신을 한 신부님</b>',
#  '<b>지구 최후의 밤</b>',
#  '<b>테라스 하우스 클로징 도어</b>',
#  '<b>브라더 오브 더 이어</b>',
#  '<b>지옥행 특급택시</b>',
#  '<b>컨트롤 그룹</b>',
#  '<b>델리리움</b>',
#  '<b>에브리타임 룩 앳 유</b>',
#  '<b>페르소나</b> 5',
#  '<b>글로리아 벨</b>',
#  '<b>몬테크리스토</b>',
#  '<b>가족이 되기까지</b>',
#  '<b>금의위-기문둔갑</b>',
#  '<b>존 윅 3: 파라벨룸</b>',
#  '<b>패트와 매트: 우당탕탕 크리스마스</b>',
#  '<b>아이스</b>',
#  '<b>최후의 전투: 중동 전쟁</b>',
#  '<b>김복동</b>',
#  '<b>소림퇴마: 악마사냥꾼</b>',
#  '<b>늑대의 아이들</b>',
#  '<b>매튜 본의 백조의 호수</b>',
#  '<b>참외향기</b>',
#  '<b>오늘 밤, 로맨스 극장에서</b>',
#  '<b>승풍파랑</b>',
#  '<b>뷰티풀 보이</b>',
#  '<b>지구 최후의 날 2019</b>',
#  '<b>안도 타다오</b>',
#  '<b>방문객</b>',
#  '<b>하루</b>',
#  '<b>무협: 절대비기의 비밀</b>',
#  '<b>악녀</b>',
#  '<b>물의 기억</b>',
#  '<b>카리스마타 살인</b>',
#  '<b>위 워 솔져스</b>',
#  '<b>정의심판</b>',
#  '<b>딥워터 엘리게이터</b>',
#  '<b>디어스킨</b>',
#  '<b>주디</b>',
#  '<b>해피타임 스파이</b>',
#  '<b>학교는 끝났다</b>',
#  '<b>노가리</b>',
#  '<b>다크 하트</b>',
#  '<b>섹션제로4: 진혼곡</b>',
#  '<b>챔피언</b>',
#  '<b>열혈형사</b>',
#  '<b>탈출</b>',
#  '<b>베스테르플라테 전투</b>',
#  '<b>킹덤</b>',
#  '<b>폴라로이드</b>',
#  '<b>기억의 밤</b>',
#  '<b>카잔자키스</b>',
#  '<b>룩 어웨이</b>',
#  '<b>스파이더맨: 파 프롬 홈</b>',
#  '<b>알.이.엠</b>',
#  '<b>하나식당</b>',
#  '<b>더 넌: 수녀의 저주</b>',
#  '<b>포르토</b> 다스 캐이샤스',
#  '<b>게이트</b>',
#  '<b>기도의 막이 내릴 때</b>',
#  '<b>이,기적인 남자</b>',
#  '<b>하우스 오브 투모로우</b>',
#  '<b>쌍둥이 에로 킬러 - 자매의 유혹</b>',
#  '<b>원 네이션</b>',
#  '<b>천로역정: 천국을 찾아서</b>',
#  '<b>피델리오</b>',
#  '<b>지푸라기라도 잡고 싶은 짐승들</b>',
#  '<b>룸 이스케이프</b>',
#  '<b>크로우 라이징</b>',
#  '<b>억남</b>',
#  '<b>퍼즐</b>',
#  '<b>산타 앤 컴퍼니</b>',
#  '<b>엠마</b>',
#  '<b>루키스</b>',
#  '<b>레나</b>',
#  '<b>포겟 미 낫-엄마에게 쓰는 편지</b>',
#  '<b>롱 리브 더 킹: 목포 영웅</b>',
#  '<b>지구 침공의 날 2019</b>',
#  '<b>사막을 건너 호수를 지나</b>',
#  '<b>보통사람</b>',
#  '<b>세상을 바꾼 변호인</b>',
#  '<b>빌로우 허</b>',
#  '<b>위대한 전진</b>',
#  '<b>파라노말 고스트</b>',
#  '<b>정복의 신 징기즈칸</b>',
#  '<b>에릭 클랩튼: 기타의 신</b>',
#  '<b>파라노말 액티비티 2019</b>',
#  '<b>애드 아스트라</b>',
#  '<b>막다른 골목의 추억</b>',
#  '<b>체인지 오버</b>',
#  '<b>퍼스트 리폼드</b>',
#  '<b>무법자-난공불락 대열차</b>',
#  '<b>데드 트리거</b>',
#  '<b>이스케이프 룸</b> 2: 노 웨이 아웃',
#  '<b>안녕, 티라노: 영원히, 함께</b>',
#  '<b>인비저블 라이프</b>',
#  '<b>타발루가와 얼음공주</b>',
#  '<b>블루스 인 인디아</b>',
#  '<b>네레우스: 바다의 괴물</b>',
#  '<b>극장판 샤이닝스타:새로운 루나퀸의 탄생</b>!',
#  '<b>경계선</b>',
#  '<b>아담스 패밀리</b>',
#  '<b>퍼펙트 스트레인저</b>',
#  '<b>썩시드</b>',
#  '<b>우먼 인 할리우드</b>',
#  '<b>무림방주: 절대고수의 탄생</b>',
#  '<b>몽마르트 파파</b>',
#  '<b>카운트다운</b>',
#  '<b>속닥속닥</b>',
#  '<b>해피 데스데이 2 유</b>',
#  '<b>아티스트: 다시 태어나다</b>',
#  '<b>열두 번째 용의자</b>',
#  '<b>빅 브라더</b>',
#  '<b>귀신의 향기</b>',
#  '<b>캐리tv 러브콘서트 더 무비</b>',
#  '<b>팡파레</b>',
#  '<b>브라 이야기</b>',
#  '<b>목격자</b> : 눈이 <b>없는</b> <b>아이</b>',
#  '파이널 <b>싸움의 기술</b>',
#  '<b>작전명 아이다호</b>',
#  '<b>방세옥-천하대전</b>',
#  '<b>지구공룡대탐험</b>',
#  '<b>스티븐 시걸의 제네럴 커맨더</b>',
#  '<b>이태원</b>',
#  '<b>옥자</b>',
#  '<b>라 파미에</b>',
#  '<b>그것: 두 번째 이야기</b>',
#  '<b>행맨</b>',
#  '<b>레플리카</b>',
#  '<b>디재스터 라이프</b>',
#  '<b>아무도 없는 곳</b>',
#  '<b>숲속왕국의 꿀벌 여왕</b>',
#  '<b>오피셜 시크릿</b>',
#  '<b>련희와 연희</b>',
#  '<b>스트롱거</b>',
#  '<b>트러블 위드 유</b>',
#  '<b>이스케이프 플랜3</b>',
#  '<b>아이즈 온 미 : 더 무비</b>',
#  '<b>어쩌다 룸메이트</b>',
#  '<b>삼국-무영자</b>',
#  '<b>싸이코 킬러</b>',
#  '<b>로빈슨의 언더워터 어드벤처</b>',
#  '마이 <b>레드 슈즈</b>',
#  '<b>스카이와 친구들: 로보시티의 비밀</b>',
#  '<b>러브 유어셀프 인 서울</b>',
#  '<b>임을 위한 행진곡</b>',
#  '<b>세상의 종말을 예언하는 소년: 프로디지</b>',
#  '<b>아직 지나지 않은 여름</b>',
#  '<b>전원사형</b>',
#  '<b>사이몬과 타카시</b>',
#  '<b>미이라 리턴즈</b>',
#  '<b>좀비랜드: 더블 탭</b>',
#  '<b>헬로우 평양</b>',
#  '<b>전주에서 길을 묻다</b>',
#  '<b>조금씩, 천천히 안녕</b>',
#  '<b>이타미 준의 바다</b>',
#  '<b>깡패들</b>',
#  '<b>살인병기 격리구역</b>',
#  '<b>이케아 옷장에서 시작된 특별난 여행</b>',
#  '<b>트리플 스렛</b>',
#  '<b>체크 메이트 캅</b>',
#  '<b>탱크: 무적의 T34</b>',
#  '<b>아이스브레이커</b>',
#  '<b>커런트 워</b>',
#  '<b>미드나잇 쇼타임</b>',
#  '<b>엑스맨: 다크 피닉스</b>',
#  '<b>모험왕 블링키</b>',
#  '<b>로드킬</b>',
#  '<b>글래스</b>',
#  '<b>거미줄에 걸린 소녀</b>',
#  '<b>말레피센트 2</b>',
#  '<b>너와 파도를 탈 수 있다면</b>',
#  '<b>우리들의 완벽한 세계</b>',
#  '<b>지금 만나러 갑니다</b>',
#  '<b>왓 데이 해드</b>',
#  '<b>샤크 베이트</b>',
#  '<b>뱅드림! 필름 라이브</b> 세컨드 스테이지',
#  '<b>고릴라와 슈퍼레이스</b>',
#  '<b>로스트 인 베를린</b>',
#  '퉈즈 <b>더</b> 나잇 비포 <b>크리스마스</b>',
#  '<b>내안의 그놈</b>',
#  '<b>다이빙: 그녀에 빠지다</b>',
#  '<b>검은 여름</b>',
#  '<b>나를 찾아서</b>',
#  '<b>닥터 두리틀</b>',
#  '<b>드라큘라: 모로이의 전설</b>',
#  '<b>폴링 스노우</b>',
#  '<b>다운시커</b>',
#  '<b>핑크퐁 시네마 콘서트 : 우주대탐험</b>',
#  '<b>미드 90</b>',
#  '<b>무현, 두 도시 이야기</b>',
#  '<b>분장</b>',
#  '<b>레드 스프링 아포칼립스</b>',
#  '<b>매리</b>',
#  '<b>월성</b>',
#  '<b>메리 크리스마스 미스터 모</b>',
#  '<b>웰컴 투 스웨덴</b>',
#  '<b>블랙 스완: 흑화</b>',
#  '<b>카나리해</b>',
#  '<b>제미니 맨</b>',
#  '<b>시크릿 웨폰</b>',
#  '<b>아드리아나 르쿠브뢰르</b>',
#  '<b>예스터데이</b>',
#  '<b>러브 라이브! 선샤인!! 더 스쿨 아이돌 무비 오버 더 레인보우</b>',
#  '<b>틴 스피릿</b>',
#  '<b>마담 프루스트의 비밀정원</b>',
#  '<b>어메이징 그레이스</b>',
#  '<b>극장판 오소마츠 6쌍둥이</b>',
#  '<b>어스</b>',
#  '<b>허슬러</b>',
#  '<b>걸작</b>',
#  '<b>다시, 봄</b>',
#  '<b>메이킹 패밀리</b>',
#  '<b>더 보이 2: 돌아온 브람스</b>',
#  '<b>라스트 씬</b>',
#  '<b>뷰티플 마인드</b>',
#  '<b>인비저블맨</b>',
#  '<b>미나리</b>',
#  '<b>다잉</b>',
#  '<b>0.0MHz</b>',
#  '<b>하이 라이프</b>',
#  '<b>오늘도 평화로운</b>',
#  '<b>어른이 되면</b>',
#  '<b>서스페리아</b>',
#  '<b>더 배드 넌</b>',
#  '<b>빅샤크2: 해저2만리</b>',
#  '<b>정글</b>',
#  '<b>마법안개의 비밀: 황금 보물선을 찾아라</b>',
#  '<b>마음에 부는 바람</b>',
#  '<b>아직 사랑하고 있습니까?</b>',
#  '<b>뮤즈</b>',
#  '<b>우리는 언제나 성에 살았다</b>',
#  '<b>존과 맥의 요상한 우주여행</b>',
#  '<b>수상한 이웃</b>',
#  '<b>더 블랙</b>',
#  '<b>할로우 차일드 숲 속의 문</b>',
#  '<b>캡틴 샤키</b>',
#  '<b>안녕, 나의 소녀 시절이여</b>',
#  '<b>번 더 스테이지: 더 무비</b>',
#  '<b>우아한 만찬</b>',
#  '<b>죄 많은 소녀</b>',
#  '프로페서 켈로그 앤 더 콜롬비안 <b>북샵</b> 크랙 어드벤처',
#  '<b>안나</b>',
#  '<b>킹스맨: 퍼스트 에이전트</b>',
#  '<b>아이카</b> 카타파',
#  '<b>로마</b>',
#  '<b>데스티네이션 웨딩</b>',
#  '<b>장난스런 키스</b>',
#  '<b>레전더리: 툼 오브 더 드래곤</b>',
#  '<b>스페셜 솔져</b>',
#  '<b>여대생 기숙사에서 생긴 일</b>',
#  '<b>마술피리</b>',
#  '<b>위선자들</b>',
#  '<b>야곱의 사다리</b>',
#  '<b>어쩌다 액션 히어로</b>',
#  '<b>심장박동조작극</b>',
#  '<b>변신</b>',
#  '<b>배신자</b>',
#  '<b>미드웨이</b>',
#  '<b>헌터 킬러</b>',
#  '<b>B급 며느리</b>',
#  '<b>비욘드 라인</b>',
#  '<b>작은 방안의 소녀</b>',
#  '자니 <b>더</b> 자이언트 <b>킬러</b>',
#  '<b>스파이더맨: 뉴 유니버스</b>',
#  '<b>7년의 밤</b>',
#  '<b>소공녀</b>',
#  '<b>구스범스: 몬스터의 역습</b>',
#  '<b>프리즌</b>',
#  '<b>조커</b> 이즈 와일드',
#  '<b>람보 : 라스트 워</b>',
#  '<b>타오르는 여인의 초상</b>',
#  '<b>소은이의 무릎</b>',
#  '<b>닥터 슬립</b>',
#  '<b>접전: 갑을 전쟁</b>',
#  '<b>해에게서 소년에게</b>',
#  '<b>쓰루 더 파이어</b>',
#  '<b>루스 베이더 긴즈버그 : 나는 반대한다</b>',
#  '<b>쥬만지: 넥스트 레벨</b>',
#  '<b>소림사: 무림퇴마전</b>',
#  '<b>크리미널 게임: 보석 사기단</b>',
#  '<b>에베레스트</b>',
#  '<b>우리 지금 만나</b>',
#  '<b>영화로운 나날</b>',
#  '<b>크레이지 리치 아시안</b>',
#  '<b>더 디너</b>',
#  '<b>원더풀 고스트</b>',
#  '<b>러브리스</b>',
#  '<b>메이트</b>',
#  '<b>공작</b>',
#  '<b>녹차의 중력</b>',
#  '<b>신데렐라:마법 반지의 비밀</b>',
#  '<b>국가부도의 날</b>',
#  '<b>피터팬: 후크 선장과 결투의 날</b>',
#  '<b>말모이</b>',
#  '<b>노크 노크</b>',
#  '<b>에움길</b>',
#  '<b>스트레인저랜드</b>',
#  '<b>하트</b>',
#  '<b>게발트 파이브:구타본능</b>',
#  '<b>올 더 머니</b>',
#  '<b>슈퍼 버드</b>',
#  '<b>투 러버스 앤 베어</b>',
#  '<b>23 아이덴티티</b>',
#  '<b>50가지 그림자: 심연</b>',
#  '<b>어쌔신즈</b>',
#  '<b>석조저택 살인사건</b>',
#  '<b>나는 다른 언어로 꿈을 꾼다</b>',
#  '<b>당신과 함께한 순간들</b>',
#  '<b>가미카제</b>',
#  '<b>제3의 사랑</b>',
#  '<b>나의 사랑, 그리스</b>',
#  '<b>프리 스테이트</b>',
#  '<b>나는 사랑과 시간과 죽음을 만났다</b>',
#  '그 <b>여자의 일생</b>',
#  '<b>하나와 미소시루</b>',
#  '<b>천하무림불패</b>',
#  '<b>미인어</b>',
#  '<b>재꽃</b>',
#  '<b>여친 엄마</b>',
#  '<b>누나 친구 2</b>',
#  '<b>마영정: 상해야인시대</b>',
#  '<b>시간위의 집</b>',
#  '<b>파이널 임팩트</b>',
#  '<b>키코리키: 황금모자의 비밀</b>',
#  '<b>LA 대지진</b>',
#  '<b>폴터가이스트 액티비티</b>',
#  '<b>너에게만 들려주고 싶어</b>',
#  '<b>바후발리: 더 비기닝</b>',
#  '<b>오즈의 마법사 2</b>',
#  '<b>위대한 임무</b>',
#  '<b>데스노트: 더 뉴 월드</b>',
#  '<b>아마도 내일은</b>',
#  '<b>더 큐어</b>',
#  '<b>가족의 재구성</b>',
#  '<b>녹화중이야</b>',
#  '<b>아기돼지 3형제와 매직램프</b>',
#  '<b>로건</b>',
#  '<b>무림지존: 천하제일검</b>',
#  '<b>내 아내와 결혼해 주세요</b>',
#  '<b>고려 아리랑: 천산의 디바</b>',
#  '<b>아버지와 이토씨</b>',
#  '<b>아토믹 블론드</b>',
#  '<b>커튼콜</b>',
#  '<b>레고 배트맨 무비</b>',
#  '능욕쾌락: 중독된 <b>여자들</b>',
#  '<b>청춘연애</b>',
#  '<b>아빠는 나의 여신</b>',
#  '<b>아뉴스 데이</b>',
#  '<b>마틴 에덴</b>',
#  '<b>패트와 매트: 뚝딱뚝딱 대소동</b>',
#  '<b>옆집소녀</b>',
#  '<b>더 파티</b>',
#  '<b>샘</b>',
#  '<b>7번째 내가 죽던 날</b>',
#  '<b>화이트 릴리</b>',
#  '<b>불륜가족</b>',
#  '<b>내 친구의 아내 3</b>',
#  '<b>리틀 프린세스 소피아: 엘레나와 비밀의 아발로 왕국</b>',
#  '<b>오두막</b>',
#  '<b>우리 연애의 이력</b>',
#  '<b>스머프: 비밀의 숲</b>',
#  '<b>런던 타운</b>',
#  '<b>샤룩칸의 팬</b>',
#  '<b>초대남</b>',
#  '<b>겟 아웃</b>',
#  '<b>콜로설</b>',
#  '<b>뮤지엄</b>',
#  '<b>초인</b>',
#  '<b>사냥</b>',
#  '<b>클레어의 카메라</b>',
#  '<b>브라더후드</b>',
#  '<b>애로우헤드</b>',
#  '<b>범죄의 여왕</b>',
#  '<b>카페, 한 사람을 기다리다</b>',
#  '<b>딥 워터 서바이벌</b>',
#  '<b>튤립 피버</b>',
#  '<b>올레</b>',
#  '<b>내 친구의 아내: 만져봐도 될까요?</b>',
#  '<b>여선생</b>2',
#  '<b>아빠는 딸</b>',
#  '<b>커터</b>',
#  '<b>더 서클</b>',
#  '<b>게임의 규칙</b>',
#  '<b>킬러의 보디가드</b> 2',
#  '<b>더 바</b>',
#  '<b>꼬마참새 리차드: 아프리카 원정대</b>',
#  '<b>트랜스포머: 최후의 기사</b>',
#  '<b>스노든</b>',
#  '<b>바람의 춤꾼</b>',
#  '<b>데블스 윙즈</b>',
#  '<b>미스 슬로운</b>',
#  '조선 <b>스캔들</b>',
#  '<b>깊은 사정</b>',
#  '<b>어떻게 헤어질까</b>',
#  '<b>패트리어트 데이</b>',
#  '<b>럭키</b>',
#  '<b>더 베일</b>',
#  '<b>더 데이: 최후의 심판</b>',
#  '<b>설행_눈길을 걷다</b>',
#  '<b>우리를 침범하는 것들</b>',
#  '<b>덩케르크</b>',
#  '<b>파워배틀 와치카: 와치가면의 역습</b>',
#  '<b>청춘 합창단 - 또 하나의 꿈</b>',
#  '<b>안티갱 스쿼드</b>',
#  ...]

# %%
df[0]
# Out:
# '스왈로 탐험대와 아마존 해적'

# %%
m = search_title(df[3])

for n in (range(len(m))):
        if m[n]['director'][:-1] == data[data['title'] == f'{keyword}']['directors'].values:
            break
        
link = m[n]['link']
spl = str(link).split("=")
it = spl[1]

# %%
it
# Out:
# '172040'

# %%
title1 = m[n]['title']
title1
# Out:
# '<b>물괴</b>'

# %%
code_lst
# Out:
# ['143399',
#  '132996',
#  '146459',
#  '172040',
#  '141221',
#  '109867',
#  '167787',
#  '169649',
#  '167647',
#  '179712',
#  '168054',
#  '178654',
#  '164102',
#  '138601',
#  '179303',
#  '174329',
#  '179446',
#  '179185',
#  '173833',
#  '172010',
#  '174305',
#  '141206',
#  '154449',
#  '167720',
#  '173469',
#  '179840',
#  '173413',
#  '162423',
#  '172194',
#  '178803',
#  '171911',
#  '170405',
#  '147029',
#  '154271',
#  '161115',
#  '179430',
#  '152632',
#  '177442',
#  '137343',
#  '170456',
#  '172145',
#  '178761',
#  '137962',
#  '179713',
#  '179250',
#  '143373',
#  '168669',
#  '144266',
#  '178632',
#  '179708',
#  '169015',
#  '144958',
#  '176711',
#  '151280',
#  '141973',
#  '141158',
#  '151117',
#  '132939',
#  '154273',
#  '164269',
#  '171238',
#  '178875',
#  '196367',
#  '174262',
#  '176746',
#  '151886',
#  '177357',
#  '168738',
#  '158620',
#  '176747',
#  '166585',
#  '163744',
#  '175318',
#  '178426',
#  '159864',
#  '78525',
#  '142683',
#  '172996',
#  '147018',
#  '116509',
#  '177497',
#  '160009',
#  '193618',
#  '164126',
#  '157172',
#  '168018',
#  '161693',
#  '109906',
#  '158191',
#  '170396',
#  '172137',
#  '177975',
#  '154982',
#  '178403',
#  '172798',
#  '164155',
#  '152621',
#  '178816',
#  '140213',
#  '178818',
#  '179187',
#  '149027',
#  '168679',
#  '168991',
#  '178429',
#  '171541',
#  '154667',
#  '35067',
#  '158112',
#  '154112',
#  '149417',
#  '142250',
#  '48971',
#  '164139',
#  '162265',
#  '168023',
#  '180361',
#  '170267',
#  '144323',
#  '168059',
#  '155263',
#  '167481',
#  '181025',
#  '163787',
#  '154669',
#  '173667',
#  '175481',
#  '189257',
#  '182713',
#  '184912',
#  '175149',
#  '177757',
#  '155715',
#  '183481',
#  '183513',
#  '147045',
#  '183275',
#  '174268',
#  '179461',
#  '183453',
#  '179667',
#  '181013',
#  '187351',
#  '158180',
#  '162295',
#  '155716',
#  '184995',
#  '162294',
#  '180374',
#  '149512',
#  '155041',
#  '182618',
#  '182619',
#  '152387',
#  '137946',
#  '186663',
#  '180429',
#  '155680',
#  '154219',
#  '185045',
#  '187597',
#  '181912',
#  '162932',
#  '180002',
#  '165458',
#  '185155',
#  '187365',
#  '200052',
#  '176622',
#  '164116',
#  '142633',
#  '182621',
#  '134891',
#  '167648',
#  '161242',
#  '158536',
#  '173653',
#  '149479',
#  '179683',
#  '181017',
#  '180687',
#  '178483',
#  '171921',
#  '181095',
#  '165809',
#  '160953',
#  '155411',
#  '182012',
#  '147036',
#  '174269',
#  '193128',
#  '152648',
#  '171466',
#  '108052',
#  '179235',
#  '164992',
#  '178871',
#  '163716',
#  '178849',
#  '167638',
#  '165020',
#  '148647',
#  '190727',
#  '143388',
#  '174832',
#  '172197',
#  '137327',
#  '145264',
#  '158178',
#  '154255',
#  '178434',
#  '183855',
#  '134895',
#  '127391',
#  '171336',
#  '186664',
#  '183479',
#  '167062',
#  '179392',
#  '15489',
#  '140649',
#  '176033',
#  '184178',
#  '183520',
#  '168049',
#  '154508',
#  '179414',
#  '174292',
#  '179689',
#  '168019',
#  '171490',
#  '183741',
#  '156195',
#  '172031',
#  '175255',
#  '163900',
#  '171414',
#  '162014',
#  '142251',
#  '172344',
#  '163824',
#  '166482',
#  '171441',
#  '169647',
#  '116146',
#  '162854',
#  '168017',
#  '162406',
#  '163664',
#  '173004',
#  '144183',
#  '174798',
#  '143416',
#  '154285',
#  '163682',
#  '174804',
#  '158890',
#  '169532',
#  '162395',
#  '153675',
#  '171888',
#  '68291',
#  '175325',
#  '118184',
#  '159805',
#  '171408',
#  '164796',
#  '163850',
#  '154292',
#  '145747',
#  '154251',
#  '171746',
#  '171443',
#  '162405',
#  '172525',
#  '168479',
#  '108360',
#  '165768',
#  '45425',
#  '174811',
#  '152680',
#  '159839',
#  '175365',
#  '175617',
#  '25992',
#  '172420',
#  '144693',
#  '163893',
#  '150097',
#  '137702',
#  '170289',
#  '171877',
#  '170637',
#  '158885',
#  '168110',
#  '159037',
#  '171744',
#  '156148',
#  '143371',
#  '166415',
#  '159834',
#  '115511',
#  '152656',
#  '168518',
#  '167482',
#  '158645',
#  '167408',
#  '143463',
#  '170953',
#  '170664',
#  '159105',
#  '169546',
#  '103304',
#  '128912',
#  '169517',
#  '157695',
#  '109960',
#  '71036',
#  '173692',
#  '150687',
#  '168418',
#  '165026',
#  '168523',
#  '168517',
#  '164337',
#  '189361',
#  '169899',
#  '129673',
#  '171768',
#  '154598',
#  '149236',
#  '118736',
#  '126052',
#  '129256',
#  '72089',
#  '172562',
#  '171764',
#  '150658',
#  '148995',
#  '151744',
#  '149501',
#  '170286',
#  '170457',
#  '154270',
#  '144942',
#  '169262',
#  '158631',
#  '154550',
#  '173784',
#  '175614',
#  '177508',
#  '169688',
#  '149702',
#  '114057',
#  '177379',
#  '172174',
#  '172472',
#  '104094',
#  '136990',
#  '173145',
#  '159670',
#  '168735',
#  '177507',
#  '164113',
#  '163660',
#  '170806',
#  '160375',
#  '33152',
#  '152661',
#  '171446',
#  '186147',
#  '167602',
#  '163851',
#  '175317',
#  '47933',
#  '167388',
#  '177335',
#  '170970',
#  '172967',
#  '177222',
#  '170824',
#  '172425',
#  '165106',
#  '127335',
#  '177378',
#  '171576',
#  '169643',
#  '177220',
#  '160721',
#  '177227',
#  '171727',
#  '177225',
#  '177381',
#  '174257',
#  '172768',
#  '174301',
#  '158621',
#  '178215',
#  '170888',
#  '165479',
#  '177368',
#  '159883',
#  '162908',
#  '172592',
#  '171727',
#  '172009',
#  '172034',
#  '163679',
#  '171754',
#  '164684',
#  '176513',
#  '160487',
#  '172600',
#  '143776',
#  '53547',
#  '171407',
#  '167763',
#  '172777',
#  '121762',
#  '118343',
#  '166463',
#  '156532',
#  '172006',
#  '66676',
#  '171822',
#  '169561',
#  '170139',
#  '154433',
#  '151740',
#  '158647',
#  '171810',
#  '159731',
#  '164747',
#  '140285',
#  '177250',
#  '159092',
#  '160699',
#  '172019',
#  '172118',
#  '171499',
#  '157340',
#  '62907',
#  '175727',
#  '173019',
#  '176896',
#  '111186',
#  '154222',
#  '176892',
#  '154625',
#  '175591',
#  '162002',
#  '178250',
#  '86605',
#  '152475',
#  '172113',
#  '144330',
#  '168030',
#  '166476',
#  '159627',
#  '152682',
#  '176743',
#  '176524',
#  '177377',
#  '189241',
#  '97631',
#  '181701',
#  '167651',
#  '140696',
#  '183494',
#  '172187',
#  '194027',
#  '187541',
#  '186616',
#  '189959',
#  '164189',
#  '193219',
#  '186349',
#  '186033',
#  '179973',
#  '184918',
#  '155218',
#  '189368',
#  '186035',
#  '216494',
#  '187411',
#  '169217',
#  '182777',
#  '185286',
#  '181144',
#  '190574',
#  '189244',
#  '183783',
#  '189292',
#  '168043',
#  '188153',
#  '182001',
#  '151151',
#  '151674',
#  '181014',
#  '154291',
#  '178857',
#  '184919',
#  '187051',
#  '189291',
#  '183803',
#  '186610',
#  '155779',
#  '150027',
#  '179482',
#  '182020',
#  '154983',
#  '186659',
#  '192364',
#  '173810',
#  '73665',
#  '174530',
#  '181104',
#  '183508',
#  '183507',
#  '173840',
#  '116135',
#  '183506',
#  '193850',
#  '174261',
#  '179397',
#  '186660',
#  '173812',
#  '159093',
#  '176040',
#  '168405',
#  '142201',
#  '119814',
#  '181717',
#  '173020',
#  '171452',
#  '140652',
#  '188360',
#  '151738',
#  '188361',
#  '173247',
#  '144990',
#  '137917',
#  '164153',
#  '193839',
#  '179666',
#  '184962',
#  '181570',
#  '181074',
#  '184204',
#  '148442',
#  '174297',
#  '181069',
#  '174265',
#  '180370',
#  '179318',
#  '119555',
#  '158622',
#  '152691',
#  '189260',
#  '190598',
#  '12906',
#  '191031',
#  '190643',
#  '189139',
#  '173575',
#  '185933',
#  '187583',
#  '167374',
#  '187508',
#  '159366',
#  '182387',
#  '52720',
#  '167054',
#  '154000',
#  '174903',
#  '178451',
#  '167605',
#  '167100',
#  '188339',
#  '181039',
#  '165748',
#  '159877',
#  '189293',
#  '158652',
#  '176738',
#  '170311',
#  '186642',
#  '162415',
#  '183457',
#  '181021',
#  '193209',
#  '189624',
#  '189621',
#  '159879',
#  '187161',
#  '161500',
#  '188765',
#  '164145',
#  '132617',
#  '180992',
#  '182736',
#  '189885',
#  '172152',
#  '174730',
#  '191086',
#  '171467',
#  '189968',
#  '182788',
#  '187635',
#  '181698',
#  '189063',
#  '181103',
#  '181037',
#  '185131',
#  '189960',
#  '182756',
#  '189023',
#  '158558',
#  '170859',
#  '159760',
#  '168029',
#  '184958',
#  '148863',
#  '180162',
#  '152168',
#  '189961',
#  '155256',
#  '184859',
#  '183502',
#  '183657',
#  '187595',
#  '169522',
#  '187874',
#  '167637',
#  '172758',
#  '178148',
#  '189619',
#  '130968',
#  '182579',
#  '169347',
#  '186704',
#  '186705',
#  '190373',
#  '184308',
#  '162203',
#  '160399',
#  '181276',
#  '167445',
#  '173123',
#  '191237',
#  '169614',
#  '179697',
#  '98834',
#  '172005',
#  '170860',
#  '170310',
#  '152659',
#  '155116',
#  '173526',
#  '183836',
#  '72033',
#  '179181',
#  '164293',
#  '184999',
#  '172200',
#  '161876',
#  '171472',
#  '191677',
#  '167675',
#  '145375',
#  '183600',
#  '179125',
#  '171736',
#  '188872',
#  '152331',
#  '137865',
#  '154429',
#  '184959',
#  '184957',
#  '166543',
#  '167335',
#  '184965',
#  '159887',
#  '174083',
#  '85331',
#  '159807',
#  '181003',
#  '179643',
#  '191548',
#  '154672',
#  '185292',
#  '187507',
#  '110387',
#  '187645',
#  '185925',
#  '175045',
#  '131553',
#  '147836',
#  '86429',
#  '179721',
#  '186672',
#  '189463',
#  '190377',
#  '172003',
#  '181411',
#  '137948',
#  '186219',
#  '177400',
#  '147872',
#  '184240',
#  '186235',
#  '180462',
#  '148304',
#  '213633',
#  '186662',
#  '186036',
#  '185638',
#  '184906',
#  '153934',
#  '143435',
#  '180349',
#  '167560',
#  '162296',
#  '144787',
#  '186044',
#  '184366',
#  '182206',
#  '146433',
#  '164979',
#  '149290',
#  '173525',
#  '167615',
#  '189027',
#  '175498',
#  '177352',
#  '142086',
#  '179127',
#  '126497',
#  '188368',
#  '180220',
#  '156466',
#  '188379',
#  '188370',
#  '170890',
#  '173804',
#  '188377',
#  '74407',
#  '185485',
#  '184320',
#  '183427',
#  '185149',
#  '183828',
#  '183480',
#  '167671',
#  '163818',
#  '183514',
#  '179671',
#  '162196',
#  '140656',
#  '186661',
#  '164125',
#  '140110',
#  '182406',
#  '163826',
#  '161868',
#  '167635',
#  '186348',
#  '179020',
#  '168298',
#  '168038',
#  '189274',
#  '208980',
#  '148000',
#  '186648',
#  '73144',
#  '164172',
#  '167097',
#  '168745',
#  '102826',
#  '159866',
#  '183478',
#  '127322',
#  '190590',
#  '190306',
#  '163786',
#  '152183',
#  '154984',
#  '181566',
#  '171474',
#  '190979',
#  '149289',
#  '189288',
#  '184975',
#  '186677',
#  '172764',
#  '189256',
#  '186707',
#  '183110',
#  '181711',
#  '164956',
#  '113170',
#  '59139',
#  '183113',
#  '181414',
#  '11004',
#  '182642',
#  '177511',
#  '130806',
#  '192121',
#  '179420',
#  '177543',
#  '27650',
#  '187310',
#  '167542',
#  '177371',
#  '72313',
#  '176912',
#  '175586',
#  '151550',
#  '181078',
#  '183870',
#  '158623',
#  '175878',
#  '159684',
#  '187390',
#  '186050',
#  '152679',
#  '190644',
#  '180397',
#  '173754',
#  '181565',
#  '179126',
#  '179841',
#  '176354',
#  '158884',
#  '168749',
#  '107438',
#  '171465',
#  '159893',
#  '192619',
#  '178097',
#  '167443',
#  '180381',
#  '119460',
#  '188350',
#  '189100',
#  '183482',
#  '137876',
#  '172070',
#  '190608',
#  '170663',
#  '180351',
#  '185268',
#  '186615',
#  '92125',
#  '162153',
#  '189900',
#  '186238',
#  '74372',
#  '171725',
#  '85578',
#  '159311',
#  '172819',
#  '146517',
#  '43233',
#  '129282',
#  '185282',
#  '170290',
#  '38578',
#  '189205',
#  '138599',
#  '184759',
#  '172605',
#  '187349',
#  '189202',
#  '143472',
#  '194295',
#  '183804',
#  '186236',
#  '168047',
#  '147040',
#  '152156',
#  '162867',
#  '174296',
#  '153687',
#  '179416',
#  '181959',
#  '164192',
#  '185479',
#  '167699',
#  '130939',
#  '167597',
#  '114262',
#  '189123',
#  '171884',
#  '163842',
#  '155547',
#  '136889',
#  '144927',
#  '144081',
#  '152257',
#  '127346',
#  '158873',
#  '158888',
#  '158790',
#  '126504',
#  '147896',
#  '136827',
#  '140792',
#  '19903',
#  '144840',
#  '159580',
#  '127383',
#  '156337',
#  '161294',
#  '161308',
#  '102638',
#  '154214',
#  '28224',
#  '148946',
#  '158485',
#  '141337',
#  '162962',
#  '129230',
#  '161323',
#  '92413',
#  '142324',
#  '160218',
#  '143372',
#  '158634',
#  '143188',
#  '160720',
#  '117787',
#  '158775',
#  '155650',
#  '151249',
#  '155228',
#  '144215',
#  '144352',
#  '132627',
#  '207320',
#  '134892',
#  '144114',
#  '146200',
#  '159286',
#  '152491',
#  '161365',
#  '159110',
#  '162148',
#  '144988',
#  '154053',
#  '163051',
#  '168507',
#  '161374',
#  '125447',
#  '134987',
#  '118966',
#  '144202',
#  '119546',
#  '164397',
#  '156083',
#  '143499',
#  '155020',
#  '143428',
#  '136899',
#  '159827',
#  '153628',
#  '163014',
#  '139701',
#  '126011',
#  '151885',
#  '125418',
#  '140730',
#  '163093',
#  '181569',
#  '143473',
#  '141490',
#  '143099',
#  '163095',
#  '204624',
#  '153342',
#  '160464',
#  '123630',
#  '134887',
#  '162260',
#  '159595',
#  '142632',
#  '195246',
#  '159402',
#  '151673',
#  '149731',
#  '140695',
#  '127389',
#  '163086',
#  '138593',
#  '129055',
#  '146480',
#  '162933',
#  '164298',
#  '140776',
#  ...]

# %%
import csv
with open('movie_buzz_codelist.csv', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(code_lst)

# %%
code_lst = pd.read_csv('movie_buzz_codelist.csv')
code_lst=list(map(float,code_lst))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-2f76408e0a39> in <module>
#       1 code_lst = pd.read_csv('movie_buzz_codelist.csv')
# ----> 2 code_lst=list(map(float,code_lst))
#
# ValueError: could not convert string to float: 'nan.1'

# %%
code
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-4786e360ddb7> in <module>
# ----> 1 code_lst.dtype(int)
#
# AttributeError: 'list' object has no attribute 'dtype'

# %% [raw]
# 가져온 고유코드로 리뷰 가져오기

# %%
from urllib.request import urlopen 
from bs4 import BeautifulSoup
import requests
import time

# %%
date_list = []
title_list2 = []


for i in code_lst.index[3000:]:
    url = f'https://movie.naver.com/movie/bi/mi/review.naver?code={code_lst[i]}'
    html =urlopen(url)
    soup = BeautifulSoup(html,'html.parser')
    w = str(soup.select('div>div>div>div>div>div>div>span>em'))
    try:
        import re
        reg = re.compile('\d')
        per_result = reg.findall(w)
        y = ''.join(per_result)
        z = int(y)//10 +2


        date_2 = []
        for page in range(1,z):
            url2 = f'https://movie.naver.com/movie/bi/mi/review.naver?code={code_lst[i]}&page={page}'
            html2 =urlopen(url2)

            soup = BeautifulSoup(html2,'html.parser')

            date_num = soup.select('li>span>em')

            date_2.extend(date_num)
            time.sleep(2) 
        y = str(date_2).split(',')
        reg = re.compile('[^a-zA-Z가-힣\>]\d*\.\d*\.\d*')
        e = ''.join(y)
        per_result = reg.findall(e)
        datetime_result = pd.to_datetime(per_result)
        date_list.append(datetime_result)

        tit = soup.select('title')
        a = str(tit).split(":")
        b =a[0].replace('[','').replace('<','').replace('title','').replace('>','').replace(' ','')
        title_list2.append(b)
    
    except:
        date_list.append(0)
        url = f'https://movie.naver.com/movie/bi/mi/review.naver?code={code_lst[i]}'
        html =urlopen(url)
        soup = BeautifulSoup(html,'html.parser')
        tit = soup.select('title')
        a = str(tit).split(":")
        b =a[0].replace('[','').replace('<','').replace('title','').replace('>','').replace(' ','')
        title_list2.append(b)
print(len(date_list))
print(len(title_list2))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 3000
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-21ce8030b5d2> in <module>
#       4
#       5 for i in code_lst.index[3000:]:
# ----> 6     url = f'https://movie.naver.com/movie/bi/mi/review.naver?code={code_lst[i]}'
#       7     html =urlopen(url)
#       8     soup = BeautifulSoup(html,'html.parser')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 3000

# %%
len(date_list)#4270
# Out:
# 3000

# %%
import csv
with open('movie_buzz23000_title.csv', 'w', newline='') as f: 
    writer = csv.writer(f) 
    writer.writerow(title_list2)

# %% [markdown]
# 밑에코드는 신경 안쓰셔도 됩니다

# %%
import pandas as pd
one_date = pd.read_csv('movie_buzz2_3000_date.csv')

# %%
one = one_date.transpose()
one.reset_index(inplace= True)

# %%
one
# Out:
#                                                   index
# 0     DatetimeIndex(['2018-04-02', '2016-06-17', '20...
# 1     DatetimeIndex(['2018-09-12', '2018-08-08', '20...
# 2     DatetimeIndex(['2017-02-22', '2016-06-23', '20...
# 3     DatetimeIndex(['2018-04-23', '2018-12-04', '20...
# 4     DatetimeIndex([], dtype='datetime64[ns]', freq...
# ...                                                 ...
# 2995  DatetimeIndex(['2019-04-08', '2019-05-30', '20...
# 2996  DatetimeIndex(['2020-10-26'], dtype='datetime6...
# 2997  DatetimeIndex(['2020-04-22', '2020-04-10', '20...
# 2998  DatetimeIndex(['2021-06-03', '2022-01-09', '20...
# 2999  DatetimeIndex(['2019-04-17', '2019-04-01', '20...
#
# [3000 rows x 1 columns]

# %%
two_date = pd.read_csv('movie_buzz2_3000~4500_datelist.csv')
three_date = pd.read_csv('movie_buzz2_4500_5199_datelist.csv')
four_date = pd.read_csv('movie_buzz2_5200~_datelist.csv')

# %%
two = two_date.transpose()
two.reset_index(inplace= True)
three = three_date.transpose()
three.reset_index(inplace= True)
four = four_date.transpose()
four.reset_index(inplace= True)

# %%
four
# Out:
#                                                   index
# 0     DatetimeIndex(['2016-03-21', '2016-04-24', '20...
# 1     DatetimeIndex(['2016-05-15', '2016-05-09', '20...
# 2     DatetimeIndex(['2016-06-30', '2016-06-30', '20...
# 3     DatetimeIndex(['2016-12-01', '2016-12-11', '20...
# 4     DatetimeIndex([], dtype='datetime64[ns]', freq...
# ...                                                 ...
# 1153  DatetimeIndex(['2013-08-18', '2014-09-18', '20...
# 1154  DatetimeIndex(['2014-12-21', '2015-01-11', '20...
# 1155  DatetimeIndex(['2014-12-09', '2015-02-13'], dt...
# 1156  DatetimeIndex(['2014-12-09', '2015-01-16', '20...
# 1157  DatetimeIndex(['2014-08-30', '2014-08-21', '20...
#
# [1158 rows x 1 columns]

# %%
#one_title = pd.read_csv('movie_buzz2_3000_title.csv')
#two_title = pd.read_csv('movie_buzz2_3000~4500_datelist.csv')
three_title = pd.read_csv('movie_buzz2_4500_5199_titlelist.csv',encoding='UTF=8')
four_title = pd.read_csv('movie_buzz2_5200~_titlelist.csv',encoding='UTF=8')

# %%
#one_title = one_title.transpose()
#one_title.reset_index(inplace= True)
#two_title = two_title.transpose()
#two_title.reset_index(inplace= True)
three_title = three_title.transpose()
three_title.reset_index(inplace= True)
four_title = four_title.transpose()
four_title.reset_index(inplace= True)

# %%
movie_buzz_df_3_4 = pd.concat([three,four], axis=0)

# %%
movie_buzz_df_3_4
# Out:
#                                                   index
# 0     DatetimeIndex(['2012-04-11', '2012-07-15', '20...
# 1     DatetimeIndex(['2012-01-29', '2012-01-11', '20...
# 2     DatetimeIndex([], dtype='datetime64[ns]', freq...
# 3     DatetimeIndex(['2012-05-25', '2012-05-18', '20...
# 4     DatetimeIndex(['2011-12-16', '2011-12-25', '20...
# ...                                                 ...
# 1153  DatetimeIndex(['2013-08-18', '2014-09-18', '20...
# 1154  DatetimeIndex(['2014-12-21', '2015-01-11', '20...
# 1155  DatetimeIndex(['2014-12-09', '2015-02-13'], dt...
# 1156  DatetimeIndex(['2014-12-09', '2015-01-16', '20...
# 1157  DatetimeIndex(['2014-08-30', '2014-08-21', '20...
#
# [1851 rows x 1 columns]

# %%
movie_buzz_df_title_3_4 = pd.concat([three,three_title], axis=1)

# %%
df = pd.DataFrame({"date":three, "title":three_title})
df
# Out:
#   File "<ipython-input-28-0a9fdc819ef2>", line 1
#     df = pd.DataFrame({("date":three), ("title":three_title)})
#                               ^
# SyntaxError: invalid syntax

# %%
#_df.to_csv('t_df.csv', index=False, )
